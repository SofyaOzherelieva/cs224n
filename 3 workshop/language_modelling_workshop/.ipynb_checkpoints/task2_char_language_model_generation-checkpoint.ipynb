# %% [markdown]
# ## Посимвольная языковая модель. Часть 2.
#
# В этом задании Вам нужно использовать написанную языковую модель для генерации воображаемых какслов.
#
# **В процессе написания Вам нужно решить следующие проблемы**:
#
# * как запоминать изменившееся состояние модели и передавать его на следующий временной шаг.
# * что будет начальным состоянием модели.
# * как понять, что слово закончилось и нужно прекратить генерацию.
#
# **Результаты**:
#
# * генератор слов на основе обученной посимвольной модели
# * посимвольные вероятности сгенерированных слов
#
# **Дополнительно**:
#
# * ускорение модели за счёт побатчевой генерации

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
import torch.nn as nn
from torch.autograd import Variable

import matplotlib.pyplot as plt
import scipy.stats as sps

# %%
def read_dataset(infile):
    df = pd.read_html(infile)
    df = df[0]
    df.columns = ["x", "y"]
    df["y"] = df["y"].astype('str')
    df = df.drop(columns=["x"])
    x = df.y.str.split("\t",expand=True,)
    if x.shape[1] == 3:
        df['word'] = x[0].str.lower()
        df['tag'] = x[2]
    else:
        df['word'] = x[0].str.lower()
        df['tag'] = x[1]
    df = df.drop(columns = ["y"])
    
    words = list(df['word'])
    tags = list(df['tag'])
    return words, tags

train_words, train_tags = read_dataset("russian-train-high")
dev_words, dev_tags = read_dataset("russian-dev")
test_words, test_tags = read_dataset("russian-covered-test")

# %%
AUXILIARY = ['\n']

# %%
class Vocabulary:
    symbols = 0
    symbol_codes= dict()
    def fit(self, data):
        """Extract unique symbols from the data, make itos (item to string) and stoi (string to index) objects"""
        symbols = set(x for elem in data for x in elem)
        self.symbols = AUXILIARY + sorted(symbols)
        # Запомните следующую строчку кода - она нужна примерно всегда
        self.symbol_codes = {s: i for i, s in enumerate(self.symbols)}
        return self

    def __len__(self):
        return len(self._symbols)

    def transform(self, data):
        """Transform data to indices
        Input:
            - data, list of strings
        Output:
            - list of list of char indices

        >>> self.transform(['word1', 'token2'])
        >>> [[24, 2, 19, 13, 3], [8, 2, 9, 1, 7, 4]]
        """
        max_len = max(map(len, train_words))
        return [[self.symbol_codes[char] for char in word] + 
                [self.symbol_codes[AUXILIARY[0]]]*(max_len - len(word) + 1) for word in data]

# %%
v = Vocabulary()
v.fit(train_words)

# %%
transforned_train_words = v.transform(train_words)
transforned_dev_words = v.transform(dev_words)
transforned_test_words = v.transform(test_words)

# %% [markdown]
# ## Генератор обучающих данных (батчей):

# %%
def batcher(data, batch_size = 4):
    random.shuffle(data)
    data = np.array(data)
    data = data.reshape(int(data.shape[0]/batch_size), batch_size, data.shape[1])
    return data

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, batch_size = 4):
        super(RNN, self).__init__()
        self.hidden_size = (batch_size, hidden_size)
        self.embedding = nn.Embedding(len(v.symbols), input_size)
        self.i2h = nn.Linear(input_size + hidden_size, hidden_size)
        self.i2o = nn.Linear(input_size + hidden_size, output_size)
        self.o2o = nn.Linear(hidden_size + output_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        emb = self.embedding(input)
        input_combined = torch.cat((emb, hidden), 1)
        hidden = self.i2h(input_combined)
        output = self.i2o(input_combined)
        output_combined = torch.cat((hidden, output), 1)
        output = self.o2o(output_combined)
        output = self.softmax(output)
        return output, hidden

    def initHidden(self):
        hidden = torch.zeros(self.hidden_size)
        return torch.nn.init.xavier_uniform_(hidden)

# %%
criterion = nn.NLLLoss()

learning_rate = 1e-3

def train(input_line_tensor):
    
    hidden = rnn.initHidden()
    rnn.zero_grad()

    loss = 0
    input_line_tensor = input_line_tensor.T
    n = len(input_line_tensor)
    for i in range(n - 1):
        input = torch.Tensor(input_line_tensor[i]).long()
        target = torch.Tensor(input_line_tensor[i+1]).long()
        output, hidden = rnn(input, hidden)
        l = criterion(output, target)
        loss += l

    loss.backward()

    for p in rnn.parameters():
        p.data.add_(-learning_rate, p.grad.data)
        
    return output, loss.item() / input_line_tensor.shape[0]

# %%
num_of_epoch = 10
batch_size = 4

rnn = RNN(10, 32, len(v.symbols), batch_size)
all_losses = []

for _ in range(num_of_epoch):
    b_train = batcher(transforned_train_words, batch_size)
    n_batches = len(b_train)
    print_every = n_batches/20
    plot_every = n_batches/20
    
    for i in range(n_batches):
        _, loss = train(b_train[i])

        if i % print_every == 0:
            print('(%d %d%%) %.4f' % (i, i / n_batches * 100, loss))

        if i % plot_every == 0:
            all_losses.append(loss)
# Out:
# (0 0%) 3.7255
# (125 5%) 0.6641
# (250 10%) 0.6206
# (375 15%) 0.6100
# (500 20%) 0.7731
# (625 25%) 0.5963
# (750 30%) 0.7117
# (875 35%) 0.4360
# (1000 40%) 0.5486
# (1125 45%) 0.6172
# (1250 50%) 0.5367
# (1375 55%) 0.7510
# (1500 60%) 0.7543
# (1625 65%) 0.6991
# (1750 70%) 0.6763
# (1875 75%) 0.4967
# (2000 80%) 0.4970
# (2125 85%) 0.6835
# (2250 90%) 0.4379
# (2375 95%) 0.6557
# (0 0%) 0.5284
# (125 5%) 0.8164
# (250 10%) 0.5140
# (375 15%) 0.4594
# (500 20%) 0.5816
# (625 25%) 0.3636
# (750 30%) 0.5350
# (875 35%) 0.5205
# (1000 40%) 0.8309
# (1125 45%) 0.6038
# (1250 50%) 0.8843
# (1375 55%) 0.4459
# (1500 60%) 0.6694
# (1625 65%) 0.5152
# (1750 70%) 0.4451
# (1875 75%) 0.4806
# (2000 80%) 0.4847
# (2125 85%) 0.7587
# (2250 90%) 0.4768
# (2375 95%) 0.4776
# (0 0%) 0.5537
# (125 5%) 0.5376
# (250 10%) 0.5184
# (375 15%) 0.8167
# (500 20%) 0.4072
# (625 25%) 0.4190
# (750 30%) 0.5295
# (875 35%) 0.4058
# (1000 40%) 0.5196
# (1125 45%) 0.5683
# (1250 50%) 0.4386
# (1375 55%) 0.4956
# (1500 60%) 0.4148
# (1625 65%) 0.4877
# (1750 70%) 0.4234
# (1875 75%) 0.4577
# (2000 80%) 0.5473
# (2125 85%) 0.5505
# (2250 90%) 0.3803
# (2375 95%) 0.3635
# (0 0%) 0.5013
# (125 5%) 0.6226
# (250 10%) 0.4276
# (375 15%) 0.5415
# (500 20%) 0.5263
# (625 25%) 0.4171
# (750 30%) 0.4511
# (875 35%) 0.6894
# (1000 40%) 0.4538
# (1125 45%) 0.3101
# (1250 50%) 0.4436
# (1375 55%) 0.5731
# (1500 60%) 0.3756
# (1625 65%) 0.4091
# (1750 70%) 0.6436
# (1875 75%) 0.4424
# (2000 80%) 0.5131
# (2125 85%) 0.6190
# (2250 90%) 0.5767
# (2375 95%) 0.4513
# (0 0%) 0.5755
# (125 5%) 0.6837
# (250 10%) 0.4492
# (375 15%) 0.4736
# (500 20%) 0.3695
# (625 25%) 0.7483
# (750 30%) 0.4180
# (875 35%) 0.3416
# (1000 40%) 0.5453
# (1125 45%) 0.4449
# (1250 50%) 0.4850
# (1375 55%) 0.4446
# (1500 60%) 0.4470
# (1625 65%) 0.4173
# (1750 70%) 0.4955
# (1875 75%) 0.5395
# (2000 80%) 0.5159
# (2125 85%) 0.3595
# (2250 90%) 0.3451
# (2375 95%) 0.4297
# (0 0%) 0.4148
# (125 5%) 0.4254
# (250 10%) 0.3998
# (375 15%) 0.5501
# (500 20%) 0.4203
# (625 25%) 0.3599
# (750 30%) 0.3861
# (875 35%) 0.5274
# (1000 40%) 0.4835
# (1125 45%) 0.4756
# (1250 50%) 0.5396
# (1375 55%) 0.4481
# (1500 60%) 0.3843
# (1625 65%) 0.3713
# (1750 70%) 0.4758
# (1875 75%) 0.4480
# (2000 80%) 0.3792
# (2125 85%) 0.3480
# (2250 90%) 0.5325
# (2375 95%) 0.3615
# (0 0%) 0.4740
# (125 5%) 0.4637
# (250 10%) 0.4594
# (375 15%) 0.5096
# (500 20%) 0.4512
# (625 25%) 0.3503
# (750 30%) 0.6118
# (875 35%) 0.4362
# (1000 40%) 0.7159
# (1125 45%) 0.4007
# (1250 50%) 0.5327
# (1375 55%) 0.4611
# (1500 60%) 0.3751
# (1625 65%) 0.3021
# (1750 70%) 0.4040
# (1875 75%) 0.5750
# (2000 80%) 0.3758
# (2125 85%) 0.6040
# (2250 90%) 0.6278
# (2375 95%) 0.4646
# (0 0%) 0.4486
# (125 5%) 0.7760
# (250 10%) 0.3932
# (375 15%) 0.3903
# (500 20%) 0.5026
# (625 25%) 0.4018
# (750 30%) 0.6828
# (875 35%) 0.4985
# (1000 40%) 0.4327
# (1125 45%) 0.4634
# (1250 50%) 0.6393
# (1375 55%) 0.4518
# (1500 60%) 0.4842
# (1625 65%) 0.4715
# (1750 70%) 0.5033
# (1875 75%) 0.4116
# (2000 80%) 0.4837
# (2125 85%) 0.7569
# (2250 90%) 0.4216
# (2375 95%) 0.3971
# (0 0%) 0.5257
# (125 5%) 0.5142
# (250 10%) 0.5350
# (375 15%) 0.5874
# (500 20%) 0.4577
# (625 25%) 0.6961
# (750 30%) 0.3945
# (875 35%) 0.5475
# (1000 40%) 0.4320
# (1125 45%) 0.4871
# (1250 50%) 0.4723
# (1375 55%) 0.4299
# (1500 60%) 0.3998
# (1625 65%) 0.4546
# (1750 70%) 0.5224
# (1875 75%) 0.5684
# (2000 80%) 0.4651
# (2125 85%) 0.5202
# (2250 90%) 0.4475
# (2375 95%) 0.5357
# (0 0%) 0.4450
# (125 5%) 0.5251
# (250 10%) 0.3902
# (375 15%) 0.4559
# (500 20%) 0.5582
# (625 25%) 0.4377
# (750 30%) 0.5220
# (875 35%) 0.3683
# (1000 40%) 0.7390
# (1125 45%) 0.5360
# (1250 50%) 0.5121
# (1375 55%) 0.4428
# (1500 60%) 0.4551
# (1625 65%) 0.4135
# (1750 70%) 0.5255
# (1875 75%) 0.4567
# (2000 80%) 0.4014
# (2125 85%) 0.4880
# (2250 90%) 0.3831
# (2375 95%) 0.4375

# %%
plt.figure(figsize = (10, 5))
plt.title("Сходимость loss модели")
plt.plot(all_losses)
plt.show()

# %% [markdown]
# ## Генерация:

# %% [markdown]
# что будет начальным состоянием модели?
# * на вход нейронной сети мы подадим одну букву и из неё будет генериться слово
#
# как понять, что слово закончилось и нужно прекратить генерацию?
# * слово закончилось, когда сгенерирован символ "\n"

# %% [markdown]
# Для того, чтобы генерировать разные слова добавили в генерацию немножно случайности. А именно теперь мы будем выбирать первую букву среди самых вероятных с помощью распределения пуассона с параметром $0.5$.

# %%
def gen(start_letter = "д"):
    with torch.no_grad():
        result = list()
        hidden = rnn.initHidden()
            
        current_letter = start_letter
        while current_letter[0] != "\n":
            input = torch.Tensor([v.symbol_codes[current_letter]]*batch_size).long()
            
            output, hidden = rnn(input, hidden)
            i = random.choice([0, 1, 2, 3])
            output = output[i]
            output_ind = np.array(-output).argsort()
            
            if(v.symbols[np.argmax(output)] == '\n'):
                pos = output_ind[0]
            else:
                pos = sps.poisson.rvs(mu = 0.5)
            x = output_ind[pos]
            
            current_letter = v.symbols[x]
            t= (current_letter, np.exp(output[x]))
            
            result.append(t)
        return result

# %% [markdown]
# Посимвольные вероятности сгенерированных слов (сгенерируем 20 слов):

# %%
for i in range(20):
    start_letter = random.choice(v.symbols)
    print("Начальная буква: ", start_letter)
    result = gen(start_letter)
    word = start_letter
    for i in result:
        word += i[0]
        
    print(word)
    print(result)
    print("------------\n")
# Out:
# Начальная буква:  х
# ходеривоть
#
# [('о', tensor(0.2875)), ('д', tensor(0.1018)), ('е', tensor(0.1238)), ('р', tensor(0.1424)), ('и', tensor(0.1759)), ('в', tensor(0.1871)), ('о', tensor(0.1155)), ('т', tensor(0.2289)), ('ь', tensor(0.5258)), ('\n', tensor(0.6499))]
# ------------
#
# Начальная буква:  ц
# цатильнывать
#
# [('а', tensor(0.3748)), ('т', tensor(0.1546)), ('и', tensor(0.1581)), ('л', tensor(0.1063)), ('ь', tensor(0.4857)), ('н', tensor(0.3921)), ('ы', tensor(0.6216)), ('в', tensor(0.0251)), ('а', tensor(0.3253)), ('т', tensor(0.4252)), ('ь', tensor(0.9021)), ('\n', tensor(0.7619))]
# ------------
#
# Начальная буква:  ё
# ёровот
#
# [('р', tensor(0.1421)), ('о', tensor(0.2063)), ('в', tensor(0.1400)), ('о', tensor(0.2182)), ('т', tensor(0.1996)), ('\n', tensor(0.1321))]
# ------------
#
# Начальная буква:  ё
# ёраскить
#
# [('р', tensor(0.1304)), ('а', tensor(0.2191)), ('с', tensor(0.1138)), ('к', tensor(0.2251)), ('и', tensor(0.3399)), ('т', tensor(0.0759)), ('ь', tensor(0.6325)), ('\n', tensor(0.6637))]
# ------------
#
# Начальная буква:  э
# эский
#
# [('с', tensor(0.1573)), ('к', tensor(0.1768)), ('и', tensor(0.2494)), ('й', tensor(0.2844)), ('\n', tensor(0.5992))]
# ------------
#
# Начальная буква:  н
# новариноват
#
# [('о', tensor(0.2075)), ('в', tensor(0.0971)), ('а', tensor(0.2345)), ('р', tensor(0.0849)), ('и', tensor(0.2966)), ('н', tensor(0.0855)), ('о', tensor(0.0972)), ('в', tensor(0.2342)), ('а', tensor(0.3388)), ('т', tensor(0.5583)), ('\n', tensor(0.0545))]
# ------------
#
# Начальная буква:  ч
# черитат
#
# [('е', tensor(0.4161)), ('р', tensor(0.1020)), ('и', tensor(0.1971)), ('т', tensor(0.1144)), ('а', tensor(0.0851)), ('т', tensor(0.1956)), ('\n', tensor(0.0388))]
# ------------
#
# Начальная буква:  б
# берериват
#
# [('е', tensor(0.2920)), ('р', tensor(0.1628)), ('е', tensor(0.1673)), ('р', tensor(0.0917)), ('и', tensor(0.2448)), ('в', tensor(0.1732)), ('а', tensor(0.4172)), ('т', tensor(0.5212)), ('\n', tensor(0.0343))]
# ------------
#
# Начальная буква:  д
# довоть
#
# [('о', tensor(0.2572)), ('в', tensor(0.1197)), ('о', tensor(0.1986)), ('т', tensor(0.1443)), ('ь', tensor(0.1225)), ('\n', tensor(0.5069))]
# ------------
#
# Начальная буква:  ы
# ыйспоть
#
# [('й', tensor(0.2467)), ('с', tensor(0.2104)), ('п', tensor(0.1506)), ('о', tensor(0.2664)), ('т', tensor(0.0826)), ('ь', tensor(0.2767)), ('\n', tensor(0.6048))]
# ------------
#
# Начальная буква:  й
# йстоловот
#
# [('с', tensor(0.3738)), ('т', tensor(0.2474)), ('о', tensor(0.1710)), ('л', tensor(0.1150)), ('о', tensor(0.1676)), ('в', tensor(0.1653)), ('о', tensor(0.1552)), ('т', tensor(0.2744)), ('\n', tensor(0.1424))]
# ------------
#
# Начальная буква:  р
# роваранат
#
# [('о', tensor(0.2452)), ('в', tensor(0.1259)), ('а', tensor(0.2617)), ('р', tensor(0.0866)), ('а', tensor(0.1271)), ('н', tensor(0.1014)), ('а', tensor(0.1326)), ('т', tensor(0.4507)), ('\n', tensor(0.0548))]
# ------------
#
# Начальная буква:  г
# гать
#
# [('а', tensor(0.1492)), ('т', tensor(0.1221)), ('ь', tensor(0.1996)), ('\n', tensor(0.4021))]
# ------------
#
# Начальная буква:  о
# орать
#
# [('р', tensor(0.1762)), ('а', tensor(0.1341)), ('т', tensor(0.1661)), ('ь', tensor(0.1683)), ('\n', tensor(0.5179))]
# ------------
#
# Начальная буква:  ю
# юриства
#
# [('р', tensor(0.1573)), ('и', tensor(0.2321)), ('с', tensor(0.0840)), ('т', tensor(0.2751)), ('в', tensor(0.1386)), ('а', tensor(0.3549)), ('\n', tensor(0.2050))]
# ------------
#
# Начальная буква:  с
# собеловать
#
# [('о', tensor(0.1107)), ('б', tensor(0.1070)), ('е', tensor(0.2010)), ('л', tensor(0.1157)), ('о', tensor(0.1656)), ('в', tensor(0.2384)), ('а', tensor(0.2467)), ('т', tensor(0.5727)), ('ь', tensor(0.8226)), ('\n', tensor(0.7766))]
# ------------
#
# Начальная буква:  щ
# щоловать
#
# [('о', tensor(0.1930)), ('л', tensor(0.0963)), ('о', tensor(0.2128)), ('в', tensor(0.1101)), ('а', tensor(0.2876)), ('т', tensor(0.6345)), ('ь', tensor(0.7717)), ('\n', tensor(0.7267))]
# ------------
#
# Начальная буква:  щ
# щативатита
#
# [('а', tensor(0.2920)), ('т', tensor(0.1907)), ('и', tensor(0.1323)), ('в', tensor(0.1084)), ('а', tensor(0.5299)), ('т', tensor(0.5792)), ('и', tensor(0.0390)), ('т', tensor(0.1893)), ('а', tensor(0.0139)), ('\n', tensor(0.2924))]
# ------------
#
# Начальная буква:  я
# ябативоть
#
# [('б', tensor(0.1290)), ('а', tensor(0.1206)), ('т', tensor(0.2840)), ('и', tensor(0.1009)), ('в', tensor(0.1910)), ('о', tensor(0.0964)), ('т', tensor(0.2131)), ('ь', tensor(0.5120)), ('\n', tensor(0.6979))]
# ------------
#
# Начальная буква:  к
# кать
#
# [('а', tensor(0.3188)), ('т', tensor(0.1782)), ('ь', tensor(0.1776)), ('\n', tensor(0.3789))]
# ------------

# %% [markdown]
# На такого блогера я бы подписалась!

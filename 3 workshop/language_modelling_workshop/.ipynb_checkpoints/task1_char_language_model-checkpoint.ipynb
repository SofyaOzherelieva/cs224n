# %% [markdown]
# ## Посимвольная языковая модель.
#
# В первом задании Вам нужно написать и обучить посимвольную нейронную языковую модель для вычисления вероятностей буквенных последовательностей (то есть слов). Такие модели используются в задачах словоизменения и распознавания/порождения звучащей речи. Для обучения модели используйте данные для русского языка из [репозитория](https://github.com/sigmorphon/conll2018/tree/master/task1/surprise).
#
# **В процессе написания Вам нужно решить следующие проблемы:**
#
# * как будет выглядеть обучающая выборка; что будет являться признаками, и что - метками классов.
# * как сделать так, чтобы модель при предсказании символа учитывала все предыдущие символы слова.
# * какие специальные символы нужно использовать.
# * как передавать в модель текущее состояние рекуррентной сети
#
# **Результаты:**
#
# * предобработчик данных,
# * генератор обучающих данных (батчей),
# * обученная модель
# * перплексия модели на настроечной выборке
# * посимвольные вероятности слов в контрольной выборке
#
# **Дополнительно:**
#
# * дополнительный вход модели (часть речи слова, другие морфологические признаки), влияет ли его добавление на перплексию
# * сравнение различных архитектур нейронной сети (FC, RNN, LSTM, QRNN, ...)

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
import torch.nn as nn
from torch.autograd import Variable
import random

# %% [markdown]
# ## Преобработка данных:

# %% [markdown]
# как будет выглядеть обучающая выборка; что будет являться признаками, и что - метками классов?
#
# * признаки: предыдущие буквы слова
#
# * таргет: одна следующая буква

# %%
# # Uncomment to download data
# !wget https://github.com/sigmorphon/conll2018/blob/master/task1/surprise/russian-train-high
# !wget https://github.com/sigmorphon/conll2018/blob/master/task1/surprise/russian-dev
# !wget https://github.com/sigmorphon/conll2018/blob/master/task1/surprise/russian-covered-test

# %% [markdown]
# Переписала функцию считывания данных, потому что прошлая мне не нравилась.

# %%
def read_dataset(infile):
    df = pd.read_html(infile)
    df = df[0]
    df.columns = ["x", "y"]
    df["y"] = df["y"].astype('str')
    df = df.drop(columns=["x"])
    x = df.y.str.split("\t",expand=True,)
    if x.shape[1] == 3:
        df['word'] = x[0].str.lower()
        df['tag'] = x[2]
    else:
        df['word'] = x[0].str.lower()
        df['tag'] = x[1]
    df = df.drop(columns = ["y"])
    
    words = list(df['word'])
    tags = list(df['tag'])
    return words, tags

train_words, train_tags = read_dataset("russian-train-high")
dev_words, dev_tags = read_dataset("russian-dev")
test_words, test_tags = read_dataset("russian-covered-test")

# %% [markdown]
# Подумайте, какие вспомогательные токены могут быть вам полезны. Выдайте им индексы от `0` до `len(AUXILIARY) - 1`

# %% [markdown]
# Нам понадобится символ конца слова!

# %%
AUXILIARY = ['\n']

# %%
class Vocabulary:
    symbols = 0
    symbol_codes= dict()
    def fit(self, data):
        """Extract unique symbols from the data, make itos (item to string) and stoi (string to index) objects"""
        symbols = set(x for elem in data for x in elem)
        self.symbols = AUXILIARY + sorted(symbols)
        # Запомните следующую строчку кода - она нужна примерно всегда
        self.symbol_codes = {s: i for i, s in enumerate(self.symbols)}
        return self

    def __len__(self):
        return len(self._symbols)

    def transform(self, data):
        """Transform data to indices
        Input:
            - data, list of strings
        Output:
            - list of list of char indices

        >>> self.transform(['word1', 'token2'])
        >>> [[24, 2, 19, 13, 3], [8, 2, 9, 1, 7, 4]]
        """
        max_len = max(map(len, train_words))
        return [[self.symbol_codes[char] for char in word] + 
                [self.symbol_codes[AUXILIARY[0]]]*(max_len - len(word) + 1) for word in data]

# %%
v = Vocabulary()
v.fit(train_words)

# %%
transforned_train_words = v.transform(train_words)
transforned_dev_words = v.transform(dev_words)
transforned_test_words = v.transform(test_words)

# %%
max_len = max(map(len, transforned_train_words))
max_len
# Out:
# 44

# %%
len(v.symbols)
# Out:
# 36

# %% [markdown]
# ## Генератор обучающих данных (батчей):

# %%
def batcher(data, batch_size = 4):
    random.shuffle(data)
    data = np.array(data)
    data = data.reshape(int(data.shape[0]/batch_size), batch_size, data.shape[1])
    return data

# %% [markdown]
# ## Модель:

# %% [markdown]
# как сделать так, чтобы модель при предсказании символа учитывала все предыдущие символы слова?
#
# * использовать, например, рекурентные сети

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, batch_size = 4):
        super(RNN, self).__init__()
        self.hidden_size = (batch_size, hidden_size)
        self.embedding = nn.Embedding(len(v.symbols), input_size)
        self.i2h = nn.Linear(input_size + hidden_size, hidden_size)
        self.i2o = nn.Linear(input_size + hidden_size, output_size)
        self.o2o = nn.Linear(hidden_size + output_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        emb = self.embedding(input)
        input_combined = torch.cat((emb, hidden), 1)
        hidden = self.i2h(input_combined)
        output = self.i2o(input_combined)
        output_combined = torch.cat((hidden, output), 1)
        output = self.o2o(output_combined)
        output = self.softmax(output)
        return output, hidden

    def initHidden(self):
        return torch.zeros(self.hidden_size)

# %%
criterion = nn.NLLLoss()

learning_rate = 1e-3

def train(input_line_tensor):
    
    hidden = rnn.initHidden()
    rnn.zero_grad()

    loss = 0
    input_line_tensor = input_line_tensor.T
    n = len(input_line_tensor)
    for i in range(n - 1):
        input = torch.Tensor(input_line_tensor[i]).long()
        target = torch.Tensor(input_line_tensor[i+1]).long()
        output, hidden = rnn(input, hidden)
        l = criterion(output, target)
        loss += l

    loss.backward()

    for p in rnn.parameters():
        p.data.add_(-learning_rate, p.grad.data)
        
    return output, loss.item() / input_line_tensor.shape[0]

# %%
num_of_epoch = 10
batch_size = 4

rnn = RNN(10, 32, len(v.symbols), batch_size)
all_losses = []

for _ in range(num_of_epoch):
    b_train = batcher(transforned_train_words, batch_size)
    n_batches = len(b_train)
    print_every = n_batches/20
    plot_every = n_batches/20
    
    for i in range(n_batches):
        _, loss = train(b_train[i])

        if i % print_every == 0:
            print('(%d %d%%) %.4f' % (i, i / n_batches * 100, loss))

        if i % plot_every == 0:
            all_losses.append(loss)
# Out:
# (0 0%) 3.4177
# (125 5%) 0.7017
# (250 10%) 0.5945
# (375 15%) 0.4802
# (500 20%) 0.6071
# (625 25%) 0.5881
# (750 30%) 0.5018
# (875 35%) 0.8285
# (1000 40%) 0.6554
# (1125 45%) 0.4568
# (1250 50%) 0.4527
# (1375 55%) 0.7584
# (1500 60%) 0.6418
# (1625 65%) 0.5086
# (1750 70%) 0.6786
# (1875 75%) 0.4385
# (2000 80%) 0.4982
# (2125 85%) 0.5685
# (2250 90%) 0.5209
# (2375 95%) 0.5150
# (0 0%) 0.5129
# (125 5%) 0.3273
# (250 10%) 0.6089
# (375 15%) 0.4460
# (500 20%) 0.3737
# (625 25%) 0.5361
# (750 30%) 0.8250
# (875 35%) 0.6269
# (1000 40%) 0.5558
# (1125 45%) 0.4192
# (1250 50%) 0.5337
# (1375 55%) 0.4647
# (1500 60%) 0.4444
# (1625 65%) 0.4725
# (1750 70%) 0.5900
# (1875 75%) 0.4742
# (2000 80%) 0.6445
# (2125 85%) 0.7479
# (2250 90%) 0.4312
# (2375 95%) 0.4929
# (0 0%) 0.3424
# (125 5%) 0.6090
# (250 10%) 0.5753
# (375 15%) 0.7280
# (500 20%) 0.5675
# (625 25%) 0.3530
# (750 30%) 0.4868
# (875 35%) 0.7001
# (1000 40%) 0.3848
# (1125 45%) 0.3745
# (1250 50%) 0.5988
# (1375 55%) 0.4878
# (1500 60%) 0.4504
# (1625 65%) 0.6515
# (1750 70%) 0.4251
# (1875 75%) 0.3995
# (2000 80%) 0.5213
# (2125 85%) 0.3540
# (2250 90%) 0.6345
# (2375 95%) 0.3434
# (0 0%) 0.7710
# (125 5%) 0.3465
# (250 10%) 0.5527
# (375 15%) 0.4308
# (500 20%) 0.4217
# (625 25%) 0.3562
# (750 30%) 0.5516
# (875 35%) 0.3904
# (1000 40%) 0.4737
# (1125 45%) 0.5579
# (1250 50%) 0.4198
# (1375 55%) 0.4547
# (1500 60%) 0.4062
# (1625 65%) 0.5053
# (1750 70%) 0.3607
# (1875 75%) 0.4970
# (2000 80%) 0.4692
# (2125 85%) 0.5403
# (2250 90%) 0.4692
# (2375 95%) 0.3267
# (0 0%) 0.4014
# (125 5%) 0.4490
# (250 10%) 0.5434
# (375 15%) 0.4999
# (500 20%) 0.4823
# (625 25%) 0.4636
# (750 30%) 0.6021
# (875 35%) 0.5002
# (1000 40%) 0.5156
# (1125 45%) 0.5941
# (1250 50%) 0.6120
# (1375 55%) 0.5108
# (1500 60%) 0.5070
# (1625 65%) 0.3947
# (1750 70%) 0.4033
# (1875 75%) 0.4285
# (2000 80%) 0.5277
# (2125 85%) 0.5801
# (2250 90%) 0.4829
# (2375 95%) 0.4696
# (0 0%) 0.4141
# (125 5%) 0.4256
# (250 10%) 0.3741
# (375 15%) 0.5387
# (500 20%) 0.4427
# (625 25%) 0.5205
# (750 30%) 0.4608
# (875 35%) 0.4933
# (1000 40%) 0.4380
# (1125 45%) 0.4526
# (1250 50%) 0.5314
# (1375 55%) 0.3749
# (1500 60%) 0.6435
# (1625 65%) 0.6569
# (1750 70%) 0.5282
# (1875 75%) 0.4553
# (2000 80%) 0.4260
# (2125 85%) 0.5435
# (2250 90%) 0.5475
# (2375 95%) 0.4556
# (0 0%) 0.3006
# (125 5%) 0.4304
# (250 10%) 0.4211
# (375 15%) 0.4893
# (500 20%) 0.5353
# (625 25%) 0.4620
# (750 30%) 0.4835
# (875 35%) 0.3292
# (1000 40%) 0.5710
# (1125 45%) 0.5050
# (1250 50%) 0.3821
# (1375 55%) 0.4683
# (1500 60%) 0.8106
# (1625 65%) 0.4142
# (1750 70%) 0.3910
# (1875 75%) 0.5102
# (2000 80%) 0.5955
# (2125 85%) 0.4237
# (2250 90%) 0.5424
# (2375 95%) 0.3860
# (0 0%) 0.5731
# (125 5%) 0.5542
# (250 10%) 0.4907
# (375 15%) 0.4557
# (500 20%) 0.5452
# (625 25%) 0.5230
# (750 30%) 0.6624
# (875 35%) 0.6155
# (1000 40%) 0.5074
# (1125 45%) 0.3774
# (1250 50%) 0.3980
# (1375 55%) 0.3091
# (1500 60%) 0.6412
# (1625 65%) 0.4458
# (1750 70%) 0.7981
# (1875 75%) 0.4737
# (2000 80%) 0.3707
# (2125 85%) 0.4255
# (2250 90%) 0.3497
# (2375 95%) 0.3435
# (0 0%) 0.4931
# (125 5%) 0.4203
# (250 10%) 0.5267
# (375 15%) 0.4271
# (500 20%) 0.5039
# (625 25%) 0.4325
# (750 30%) 0.5818
# (875 35%) 0.4403
# (1000 40%) 0.3825
# (1125 45%) 0.5067
# (1250 50%) 0.3132
# (1375 55%) 0.5100
# (1500 60%) 0.7209
# (1625 65%) 0.5395
# (1750 70%) 0.4250
# (1875 75%) 0.4672
# (2000 80%) 0.4161
# (2125 85%) 0.4069
# (2250 90%) 0.4605
# (2375 95%) 0.3678
# (0 0%) 0.5767
# (125 5%) 0.4424
# (250 10%) 0.5980
# (375 15%) 0.4074
# (500 20%) 0.7672
# (625 25%) 0.5090
# (750 30%) 0.5041
# (875 35%) 0.5093
# (1000 40%) 0.4839
# (1125 45%) 0.7347
# (1250 50%) 0.4957
# (1375 55%) 0.7550
# (1500 60%) 0.5034
# (1625 65%) 0.4603
# (1750 70%) 0.3539
# (1875 75%) 0.5286
# (2000 80%) 0.4867
# (2125 85%) 0.4303
# (2250 90%) 0.4065
# (2375 95%) 0.5314

# %%
plt.figure(figsize = (10, 5))
plt.title("Сходимость loss модели")
plt.plot(all_losses)
plt.show()

# %% [markdown]
# Сошелся

# %% [markdown]
# ## Перплексия модели на настроечной выборке:

# %%
b_dev = batcher(transforned_dev_words, batch_size)
b_test = batcher(transforned_test_words, batch_size)

# %%
def test(input_line_tensor):
    with torch.no_grad():
        value = np.empty((), dtype=object)
        value[()] = (0, 0)
        prob = np.full((batch_size, max_len+1), value, dtype=object)
        loss= 0
        hidden = rnn.initHidden()
        input_line_tensor = input_line_tensor.T
        
        for k, one in enumerate(input_line_tensor[0]):
            t= (v.symbols[one], 0)
            prob[k][0] = t
            
        for i in range(max_len-1):
            input = torch.Tensor(input_line_tensor[i]).long()
            target = torch.Tensor(input_line_tensor[i+1]).long()
            
            output, hidden = rnn(input, hidden)
            
            l = criterion(output, target)
            
            output = np.exp(output)
            
            for k, one in enumerate(target):
                t= (v.symbols[one], output[k][one])
                prob[k][i+1] = t
            
            loss += l

        return prob, loss/max_len

# %%
for num, i in enumerate(b_dev):
    total_loss = test(i)[1]

# %%
print("Перплексия модели на настроечной выборке:", float(2**(total_loss/len(b_dev))))
# Out:
# Перплексия модели на настроечной выборке: 1.0011168718338013

# %% [markdown]
# ## Посимвольные вероятности слов в контрольной выборке:

# %% [markdown]
# Посмотрим на первые 100 слов

# %%
i = 0
for batch in b_test[:100]:
    for num in range(batch.shape[0]):
        res = test(batch)[0][num]
        
        word = ""
        for c in res:
            if c[0] == '\n':
                break
            word += c[0]
            
        print(word)

        str([c[0] for c in res])
        for k in range(len(word)):
            print(res[k + 1])
        i+= 1
# Out:
# тормошить
# ('о', tensor(0.1597))
# ('р', tensor(0.1751))
# ('м', tensor(0.0366))
# ('о', tensor(0.1372))
# ('ш', tensor(0.0217))
# ('и', tensor(0.1939))
# ('т', tensor(0.2407))
# ('ь', tensor(0.6321))
# ('\n', tensor(0.7579))
# сланец
# ('л', tensor(0.0584))
# ('а', tensor(0.1591))
# ('н', tensor(0.0881))
# ('е', tensor(0.0768))
# ('ц', tensor(0.0275))
# ('\n', tensor(0.1503))
# артериальный
# ('р', tensor(0.1217))
# ('т', tensor(0.0121))
# ('е', tensor(0.2183))
# ('р', tensor(0.2344))
# ('и', tensor(0.1208))
# ('а', tensor(0.0060))
# ('л', tensor(0.0691))
# ('ь', tensor(0.6582))
# ('н', tensor(0.4394))
# ('ы', tensor(0.7271))
# ('й', tensor(0.9232))
# ('\n', tensor(0.9780))
# пренебрежительный
# ('р', tensor(0.3178))
# ('е', tensor(0.1433))
# ('н', tensor(0.0905))
# ('е', tensor(0.1538))
# ('б', tensor(0.0092))
# ('р', tensor(0.0391))
# ('е', tensor(0.1706))
# ('ж', tensor(0.0138))
# ('и', tensor(0.1871))
# ('т', tensor(0.1604))
# ('е', tensor(0.0647))
# ('л', tensor(0.1334))
# ('ь', tensor(0.7066))
# ('н', tensor(0.3376))
# ('ы', tensor(0.6749))
# ('й', tensor(0.9205))
# ('\n', tensor(0.9796))
# устный
# ('с', tensor(0.0923))
# ('т', tensor(0.1665))
# ('н', tensor(0.0133))
# ('ы', tensor(0.1274))
# ('й', tensor(0.7766))
# ('\n', tensor(0.9531))
# овчарня
# ('в', tensor(0.0862))
# ('ч', tensor(0.0027))
# ('а', tensor(0.1518))
# ('р', tensor(0.0572))
# ('н', tensor(0.1201))
# ('я', tensor(0.0296))
# ('\n', tensor(0.2395))
# колодка
# ('о', tensor(0.1939))
# ('л', tensor(0.1704))
# ('о', tensor(0.1770))
# ('д', tensor(0.0819))
# ('к', tensor(0.0596))
# ('а', tensor(0.3929))
# ('\n', tensor(0.5192))
# понимающий
# ('о', tensor(0.2441))
# ('н', tensor(0.0370))
# ('и', tensor(0.1004))
# ('м', tensor(0.0295))
# ('а', tensor(0.1595))
# ('ю', tensor(0.0015))
# ('щ', tensor(0.0059))
# ('и', tensor(0.5697))
# ('й', tensor(0.4724))
# ('\n', tensor(0.9408))
# замкнутость
# ('а', tensor(0.2866))
# ('м', tensor(0.0571))
# ('к', tensor(0.0263))
# ('н', tensor(0.0096))
# ('у', tensor(0.0400))
# ('т', tensor(0.3534))
# ('о', tensor(0.0119))
# ('с', tensor(0.1609))
# ('т', tensor(0.3074))
# ('ь', tensor(0.1886))
# ('\n', tensor(0.7666))
# жребий
# ('р', tensor(0.0609))
# ('е', tensor(0.1347))
# ('б', tensor(0.0256))
# ('и', tensor(0.1273))
# ('й', tensor(0.0415))
# ('\n', tensor(0.8320))
# фракция
# ('р', tensor(0.3170))
# ('а', tensor(0.1806))
# ('к', tensor(0.0579))
# ('ц', tensor(0.0048))
# ('и', tensor(0.4698))
# ('я', tensor(0.3696))
# ('\n', tensor(0.7356))
# аргумент
# ('р', tensor(0.1217))
# ('г', tensor(0.0175))
# ('у', tensor(0.0936))
# ('м', tensor(0.0355))
# ('е', tensor(0.0742))
# ('н', tensor(0.2496))
# ('т', tensor(0.0978))
# ('\n', tensor(0.0121))
# объёмчик
# ('б', tensor(0.1613))
# ('ъ', tensor(0.0037))
# ('ё', tensor(0.0021))
# ('м', tensor(0.0994))
# ('ч', tensor(0.0335))
# ('и', tensor(0.2604))
# ('к', tensor(0.1461))
# ('\n', tensor(0.5080))
# квадратик
# ('в', tensor(0.0133))
# ('а', tensor(0.3265))
# ('д', tensor(0.0688))
# ('р', tensor(0.0267))
# ('а', tensor(0.3125))
# ('т', tensor(0.2530))
# ('и', tensor(0.0452))
# ('к', tensor(0.0747))
# ('\n', tensor(0.3905))
# американизм
# ('м', tensor(0.0369))
# ('е', tensor(0.1453))
# ('р', tensor(0.1443))
# ('и', tensor(0.1437))
# ('к', tensor(0.0678))
# ('а', tensor(0.2558))
# ('н', tensor(0.0749))
# ('и', tensor(0.1413))
# ('з', tensor(0.0155))
# ('м', tensor(0.0080))
# ('\n', tensor(0.0338))
# раввин
# ('а', tensor(0.3341))
# ('в', tensor(0.0509))
# ('в', tensor(0.0019))
# ('и', tensor(0.1334))
# ('н', tensor(0.1076))
# ('\n', tensor(0.0175))
# шутовской
# ('у', tensor(0.0507))
# ('т', tensor(0.1032))
# ('о', tensor(0.1070))
# ('в', tensor(0.1246))
# ('с', tensor(0.0068))
# ('к', tensor(0.0826))
# ('о', tensor(0.0741))
# ('й', tensor(0.5332))
# ('\n', tensor(0.8671))
# ночной
# ('о', tensor(0.1636))
# ('ч', tensor(0.0184))
# ('н', tensor(0.0986))
# ('о', tensor(0.1065))
# ('й', tensor(0.0258))
# ('\n', tensor(0.8197))
# дисциплинарный
# ('и', tensor(0.0557))
# ('с', tensor(0.0706))
# ('ц', tensor(0.0085))
# ('и', tensor(0.3584))
# ('п', tensor(0.0126))
# ('л', tensor(0.0916))
# ('и', tensor(0.2004))
# ('н', tensor(0.2418))
# ('а', tensor(0.0889))
# ('р', tensor(0.0223))
# ('н', tensor(0.1034))
# ('ы', tensor(0.6430))
# ('й', tensor(0.9627))
# ('\n', tensor(0.9748))
# июнь
# ('ю', tensor(0.0020))
# ('н', tensor(0.0392))
# ('ь', tensor(0.0005))
# ('\n', tensor(0.3200))
# глагол
# ('л', tensor(0.0235))
# ('а', tensor(0.1198))
# ('г', tensor(0.1013))
# ('о', tensor(0.1400))
# ('л', tensor(0.0954))
# ('\n', tensor(0.0561))
# сонар
# ('о', tensor(0.1273))
# ('н', tensor(0.0356))
# ('а', tensor(0.0801))
# ('р', tensor(0.0589))
# ('\n', tensor(0.0274))
# девяностолетний
# ('е', tensor(0.1739))
# ('в', tensor(0.0366))
# ('я', tensor(0.0153))
# ('н', tensor(0.1811))
# ('о', tensor(0.0687))
# ('с', tensor(0.0930))
# ('т', tensor(0.4445))
# ('о', tensor(0.0849))
# ('л', tensor(0.0975))
# ('е', tensor(0.0899))
# ('т', tensor(0.1682))
# ('н', tensor(0.0461))
# ('и', tensor(0.1418))
# ('й', tensor(0.3099))
# ('\n', tensor(0.9639))
# рязанский
# ('я', tensor(0.0080))
# ('з', tensor(0.1395))
# ('а', tensor(0.1302))
# ('н', tensor(0.0994))
# ('с', tensor(0.0308))
# ('к', tensor(0.1485))
# ('и', tensor(0.3645))
# ('й', tensor(0.7659))
# ('\n', tensor(0.9271))
# заблестеть
# ('а', tensor(0.2866))
# ('б', tensor(0.1046))
# ('л', tensor(0.0300))
# ('е', tensor(0.2019))
# ('с', tensor(0.0457))
# ('т', tensor(0.4801))
# ('е', tensor(0.1343))
# ('т', tensor(0.1125))
# ('ь', tensor(0.8365))
# ('\n', tensor(0.7866))
# кровоснабжение
# ('р', tensor(0.1347))
# ('о', tensor(0.1501))
# ('в', tensor(0.1364))
# ('о', tensor(0.1832))
# ('с', tensor(0.0533))
# ('н', tensor(0.0460))
# ('а', tensor(0.1880))
# ('б', tensor(0.0045))
# ('ж', tensor(0.0010))
# ('е', tensor(0.1405))
# ('н', tensor(0.1817))
# ('и', tensor(0.1100))
# ('е', tensor(0.0618))
# ('\n', tensor(0.6942))
# заношенный
# ('а', tensor(0.2866))
# ('н', tensor(0.0673))
# ('о', tensor(0.1137))
# ('ш', tensor(0.0158))
# ('е', tensor(0.0445))
# ('н', tensor(0.1522))
# ('н', tensor(0.2216))
# ('ы', tensor(0.6141))
# ('й', tensor(0.9303))
# ('\n', tensor(0.9702))
# бесспорный
# ('е', tensor(0.2193))
# ('с', tensor(0.1771))
# ('с', tensor(0.0442))
# ('п', tensor(0.0363))
# ('о', tensor(0.2390))
# ('р', tensor(0.0946))
# ('н', tensor(0.1105))
# ('ы', tensor(0.4492))
# ('й', tensor(0.9051))
# ('\n', tensor(0.9652))
# джинсовый
# ('ж', tensor(0.0013))
# ('и', tensor(0.2457))
# ('н', tensor(0.0471))
# ('с', tensor(0.0324))
# ('о', tensor(0.0894))
# ('в', tensor(0.2078))
# ('ы', tensor(0.1107))
# ('й', tensor(0.7748))
# ('\n', tensor(0.9338))
# теизм
# ('е', tensor(0.2143))
# ('и', tensor(0.0006))
# ('з', tensor(0.0466))
# ('м', tensor(0.0347))
# ('\n', tensor(0.0076))
# испражнение
# ('с', tensor(0.0922))
# ('п', tensor(0.0950))
# ('р', tensor(0.3021))
# ('а', tensor(0.1977))
# ('ж', tensor(0.0371))
# ('н', tensor(0.1342))
# ('е', tensor(0.0653))
# ('н', tensor(0.2505))
# ('и', tensor(0.1216))
# ('е', tensor(0.0495))
# ('\n', tensor(0.6280))
# переустроить
# ('е', tensor(0.1352))
# ('р', tensor(0.2275))
# ('е', tensor(0.1681))
# ('у', tensor(0.0028))
# ('с', tensor(0.0572))
# ('т', tensor(0.3414))
# ('р', tensor(0.0983))
# ('о', tensor(0.1579))
# ('и', tensor(0.0129))
# ('т', tensor(0.2479))
# ('ь', tensor(0.7772))
# ('\n', tensor(0.8253))
# снайперский
# ('н', tensor(0.0135))
# ('а', tensor(0.1125))
# ('й', tensor(0.0046))
# ('п', tensor(0.0205))
# ('е', tensor(0.0418))
# ('р', tensor(0.1002))
# ('с', tensor(0.0364))
# ('к', tensor(0.1398))
# ('и', tensor(0.4241))
# ('й', tensor(0.7526))
# ('\n', tensor(0.9334))
# родительный
# ('о', tensor(0.1981))
# ('д', tensor(0.0895))
# ('и', tensor(0.1101))
# ('т', tensor(0.1567))
# ('е', tensor(0.1080))
# ('л', tensor(0.1999))
# ('ь', tensor(0.6851))
# ('н', tensor(0.5128))
# ('ы', tensor(0.7253))
# ('й', tensor(0.9316))
# ('\n', tensor(0.9751))
# водонапорный
# ('о', tensor(0.1924))
# ('д', tensor(0.0969))
# ('о', tensor(0.2029))
# ('н', tensor(0.0724))
# ('а', tensor(0.1084))
# ('п', tensor(0.0071))
# ('о', tensor(0.0789))
# ('р', tensor(0.0512))
# ('н', tensor(0.0990))
# ('ы', tensor(0.5872))
# ('й', tensor(0.9447))
# ('\n', tensor(0.9717))
# синеватый
# ('и', tensor(0.0260))
# ('н', tensor(0.0557))
# ('е', tensor(0.2575))
# ('в', tensor(0.0374))
# ('а', tensor(0.2282))
# ('т', tensor(0.4959))
# ('ы', tensor(0.0074))
# ('й', tensor(0.4196))
# ('\n', tensor(0.9647))
# уголье
# ('г', tensor(0.0403))
# ('о', tensor(0.1190))
# ('л', tensor(0.0812))
# ('ь', tensor(0.0929))
# ('е', tensor(0.0202))
# ('\n', tensor(0.2401))
# игристый
# ('г', tensor(0.0272))
# ('р', tensor(0.1809))
# ('и', tensor(0.1054))
# ('с', tensor(0.0999))
# ('т', tensor(0.2837))
# ('ы', tensor(0.0209))
# ('й', tensor(0.6525))
# ('\n', tensor(0.9491))
# вытягивать
# ('ы', tensor(0.1032))
# ('т', tensor(0.1694))
# ('я', tensor(0.0078))
# ('г', tensor(0.0109))
# ('и', tensor(0.1291))
# ('в', tensor(0.1352))
# ('а', tensor(0.3225))
# ('т', tensor(0.4804))
# ('ь', tensor(0.8817))
# ('\n', tensor(0.8046))
# подлинность
# ('о', tensor(0.2441))
# ('д', tensor(0.1116))
# ('л', tensor(0.0385))
# ('и', tensor(0.0915))
# ('н', tensor(0.1403))
# ('н', tensor(0.1793))
# ('о', tensor(0.0236))
# ('с', tensor(0.0663))
# ('т', tensor(0.4612))
# ('ь', tensor(0.4779))
# ('\n', tensor(0.7419))
# орлица
# ('р', tensor(0.1401))
# ('л', tensor(0.0322))
# ('и', tensor(0.1035))
# ('ц', tensor(0.0206))
# ('а', tensor(0.1898))
# ('\n', tensor(0.2190))
# необъятный
# ('е', tensor(0.2309))
# ('о', tensor(0.0035))
# ('б', tensor(0.1397))
# ('ъ', tensor(0.0018))
# ('я', tensor(0.0007))
# ('т', tensor(0.0848))
# ('н', tensor(0.0532))
# ('ы', tensor(0.3588))
# ('й', tensor(0.9106))
# ('\n', tensor(0.9832))
# равносторонний треугольник
# ('а', tensor(0.3341))
# ('в', tensor(0.0509))
# ('н', tensor(0.0587))
# ('о', tensor(0.0938))
# ('с', tensor(0.0717))
# ('т', tensor(0.5281))
# ('о', tensor(0.0641))
# ('р', tensor(0.0831))
# ('о', tensor(0.0705))
# ('н', tensor(0.0825))
# ('н', tensor(0.2213))
# ('и', tensor(0.0293))
# ('й', tensor(0.2295))
# (' ', tensor(0.0152))
# ('т', tensor(0.2133))
# ('р', tensor(0.0747))
# ('е', tensor(0.1872))
# ('у', tensor(0.0008))
# ('г', tensor(0.0201))
# ('о', tensor(0.0433))
# ('л', tensor(0.0533))
# ('ь', tensor(0.2138))
# ('н', tensor(0.3245))
# ('и', tensor(0.0496))
# ('к', tensor(0.1389))
# ('\n', tensor(0.7803))
# башкирский
# ('а', tensor(0.1437))
# ('ш', tensor(0.0074))
# ('к', tensor(0.0956))
# ('и', tensor(0.2415))
# ('р', tensor(0.0670))
# ('с', tensor(0.0207))
# ('к', tensor(0.1301))
# ('и', tensor(0.3527))
# ('й', tensor(0.6922))
# ('\n', tensor(0.9345))
# приостановить
# ('р', tensor(0.3178))
# ('и', tensor(0.1718))
# ('о', tensor(0.0130))
# ('с', tensor(0.0432))
# ('т', tensor(0.5054))
# ('а', tensor(0.1559))
# ('н', tensor(0.0694))
# ('о', tensor(0.0406))
# ('в', tensor(0.1183))
# ('и', tensor(0.1472))
# ('т', tensor(0.3756))
# ('ь', tensor(0.8682))
# ('\n', tensor(0.7952))
# итальянка
# ('т', tensor(0.1103))
# ('а', tensor(0.0514))
# ('л', tensor(0.2102))
# ('ь', tensor(0.3685))
# ('я', tensor(0.0010))
# ('н', tensor(0.1528))
# ('к', tensor(0.0246))
# ('а', tensor(0.3161))
# ('\n', tensor(0.8127))
# иллюстрированный
# ('л', tensor(0.0571))
# ('л', tensor(0.0461))
# ('ю', tensor(0.0282))
# ('с', tensor(0.0122))
# ('т', tensor(0.3566))
# ('р', tensor(0.0682))
# ('и', tensor(0.1086))
# ('р', tensor(0.0101))
# ('о', tensor(0.0873))
# ('в', tensor(0.3370))
# ('а', tensor(0.3372))
# ('н', tensor(0.1336))
# ('н', tensor(0.2242))
# ('ы', tensor(0.7958))
# ('й', tensor(0.9384))
# ('\n', tensor(0.9744))
# выковыривать
# ('ы', tensor(0.1032))
# ('к', tensor(0.0187))
# ('о', tensor(0.0816))
# ('в', tensor(0.0850))
# ('ы', tensor(0.0448))
# ('р', tensor(0.0032))
# ('и', tensor(0.1492))
# ('в', tensor(0.1789))
# ('а', tensor(0.3461))
# ('т', tensor(0.5198))
# ('ь', tensor(0.9047))
# ('\n', tensor(0.8150))
# любопытство
# ('ю', tensor(0.0267))
# ('б', tensor(0.0181))
# ('о', tensor(0.1667))
# ('п', tensor(0.0260))
# ('ы', tensor(0.0031))
# ('т', tensor(0.1499))
# ('с', tensor(0.0031))
# ('т', tensor(0.3152))
# ('в', tensor(0.0322))
# ('о', tensor(0.1526))
# ('\n', tensor(0.0905))
# противопоставление
# ('р', tensor(0.3178))
# ('о', tensor(0.2396))
# ('т', tensor(0.0294))
# ('и', tensor(0.1005))
# ('в', tensor(0.0932))
# ('о', tensor(0.1198))
# ('п', tensor(0.0096))
# ('о', tensor(0.1007))
# ('с', tensor(0.0648))
# ('т', tensor(0.4025))
# ('а', tensor(0.1449))
# ('в', tensor(0.0659))
# ('л', tensor(0.0179))
# ('е', tensor(0.1905))
# ('н', tensor(0.5091))
# ('и', tensor(0.1284))
# ('е', tensor(0.0684))
# ('\n', tensor(0.6821))
# неразрывный
# ('е', tensor(0.2309))
# ('р', tensor(0.1342))
# ('а', tensor(0.1221))
# ('з', tensor(0.0394))
# ('р', tensor(0.0062))
# ('ы', tensor(0.0894))
# ('в', tensor(0.2181))
# ('н', tensor(0.0393))
# ('ы', tensor(0.4093))
# ('й', tensor(0.9145))
# ('\n', tensor(0.9712))
# симпатизировать
# ('и', tensor(0.0260))
# ('м', tensor(0.0793))
# ('п', tensor(0.0268))
# ('а', tensor(0.1038))
# ('т', tensor(0.2096))
# ('и', tensor(0.0515))
# ('з', tensor(0.0268))
# ('и', tensor(0.1197))
# ('р', tensor(0.0128))
# ('о', tensor(0.1043))
# ('в', tensor(0.3139))
# ('а', tensor(0.3554))
# ('т', tensor(0.4586))
# ('ь', tensor(0.8470))
# ('\n', tensor(0.7824))
# фригидный
# ('р', tensor(0.3170))
# ('и', tensor(0.1236))
# ('г', tensor(0.0247))
# ('и', tensor(0.1203))
# ('д', tensor(0.0123))
# ('н', tensor(0.0580))
# ('ы', tensor(0.5371))
# ('й', tensor(0.9506))
# ('\n', tensor(0.9676))
# вибрировать
# ('и', tensor(0.0445))
# ('б', tensor(0.0109))
# ('р', tensor(0.0559))
# ('и', tensor(0.0720))
# ('р', tensor(0.0232))
# ('о', tensor(0.1200))
# ('в', tensor(0.3405))
# ('а', tensor(0.3624))
# ('т', tensor(0.5302))
# ('ь', tensor(0.8650))
# ('\n', tensor(0.7157))
# оружие
# ('р', tensor(0.1401))
# ('у', tensor(0.0511))
# ('ж', tensor(0.0738))
# ('и', tensor(0.3013))
# ('е', tensor(0.0116))
# ('\n', tensor(0.1786))
# счетоводство
# ('ч', tensor(0.0097))
# ('е', tensor(0.2395))
# ('т', tensor(0.0559))
# ('о', tensor(0.0706))
# ('в', tensor(0.1706))
# ('о', tensor(0.1175))
# ('д', tensor(0.0349))
# ('с', tensor(0.0646))
# ('т', tensor(0.1679))
# ('в', tensor(0.0438))
# ('о', tensor(0.1476))
# ('\n', tensor(0.0655))
# невозможный
# ('е', tensor(0.2309))
# ('в', tensor(0.0242))
# ('о', tensor(0.1563))
# ('з', tensor(0.0239))
# ('м', tensor(0.0461))
# ('о', tensor(0.1044))
# ('ж', tensor(0.0236))
# ('н', tensor(0.0862))
# ('ы', tensor(0.5144))
# ('й', tensor(0.8918))
# ('\n', tensor(0.9699))
# цирюльня
# ('и', tensor(0.1817))
# ('р', tensor(0.1511))
# ('ю', tensor(0.0016))
# ('л', tensor(0.0962))
# ('ь', tensor(0.0882))
# ('н', tensor(0.4608))
# ('я', tensor(0.0730))
# ('\n', tensor(0.4987))
# тупизна
# ('у', tensor(0.0451))
# ('п', tensor(0.0996))
# ('и', tensor(0.1922))
# ('з', tensor(0.0383))
# ('н', tensor(0.0925))
# ('а', tensor(0.0915))
# ('\n', tensor(0.1242))
# пробирать
# ('р', tensor(0.3178))
# ('о', tensor(0.2396))
# ('б', tensor(0.0899))
# ('и', tensor(0.1527))
# ('р', tensor(0.0580))
# ('а', tensor(0.3086))
# ('т', tensor(0.3586))
# ('ь', tensor(0.8172))
# ('\n', tensor(0.7221))
# чревоугодничать
# ('р', tensor(0.0089))
# ('е', tensor(0.2262))
# ('в', tensor(0.0547))
# ('о', tensor(0.1564))
# ('у', tensor(0.0034))
# ('г', tensor(0.0327))
# ('о', tensor(0.0695))
# ('д', tensor(0.0295))
# ('н', tensor(0.0956))
# ('и', tensor(0.0779))
# ('ч', tensor(0.0202))
# ('а', tensor(0.1280))
# ('т', tensor(0.2301))
# ('ь', tensor(0.7624))
# ('\n', tensor(0.8318))
# сосредоточиться
# ('о', tensor(0.1273))
# ('с', tensor(0.0372))
# ('р', tensor(0.0145))
# ('е', tensor(0.1119))
# ('д', tensor(0.0971))
# ('о', tensor(0.1063))
# ('т', tensor(0.1251))
# ('о', tensor(0.0411))
# ('ч', tensor(0.0255))
# ('и', tensor(0.2680))
# ('т', tensor(0.2128))
# ('ь', tensor(0.7063))
# ('с', tensor(0.1240))
# ('я', tensor(0.8017))
# ('\n', tensor(0.9295))
# навьючивание
# ('а', tensor(0.1583))
# ('в', tensor(0.0211))
# ('ь', tensor(0.0052))
# ('ю', tensor(0.0020))
# ('ч', tensor(0.0035))
# ('и', tensor(0.3771))
# ('в', tensor(0.0745))
# ('а', tensor(0.3066))
# ('н', tensor(0.1134))
# ('и', tensor(0.1518))
# ('е', tensor(0.0590))
# ('\n', tensor(0.6130))
# желтеть
# ('е', tensor(0.2039))
# ('л', tensor(0.0942))
# ('т', tensor(0.0062))
# ('е', tensor(0.1990))
# ('т', tensor(0.0494))
# ('ь', tensor(0.4595))
# ('\n', tensor(0.8128))
# заглянуть
# ('а', tensor(0.2866))
# ('г', tensor(0.0627))
# ('л', tensor(0.0531))
# ('я', tensor(0.1103))
# ('н', tensor(0.2764))
# ('у', tensor(0.0108))
# ('т', tensor(0.4853))
# ('ь', tensor(0.8097))
# ('\n', tensor(0.7848))
# беспризорный
# ('е', tensor(0.2193))
# ('с', tensor(0.1771))
# ('п', tensor(0.1600))
# ('р', tensor(0.2000))
# ('и', tensor(0.1801))
# ('з', tensor(0.0579))
# ('о', tensor(0.0584))
# ('р', tensor(0.0186))
# ('н', tensor(0.1146))
# ('ы', tensor(0.5599))
# ('й', tensor(0.9465))
# ('\n', tensor(0.9662))
# отрадный
# ('т', tensor(0.0412))
# ('р', tensor(0.2358))
# ('а', tensor(0.2407))
# ('д', tensor(0.0647))
# ('н', tensor(0.1156))
# ('ы', tensor(0.4764))
# ('й', tensor(0.9400))
# ('\n', tensor(0.9615))
# древнеисландский
# ('р', tensor(0.0745))
# ('е', tensor(0.2225))
# ('в', tensor(0.0893))
# ('н', tensor(0.0798))
# ('е', tensor(0.2386))
# ('и', tensor(0.0021))
# ('с', tensor(0.1137))
# ('л', tensor(0.0407))
# ('а', tensor(0.2073))
# ('н', tensor(0.2305))
# ('д', tensor(0.0038))
# ('с', tensor(0.0130))
# ('к', tensor(0.1476))
# ('и', tensor(0.2432))
# ('й', tensor(0.7838))
# ('\n', tensor(0.9408))
# изнемогать
# ('з', tensor(0.1023))
# ('н', tensor(0.0498))
# ('е', tensor(0.1544))
# ('м', tensor(0.0372))
# ('о', tensor(0.0748))
# ('г', tensor(0.0298))
# ('а', tensor(0.0879))
# ('т', tensor(0.2999))
# ('ь', tensor(0.7880))
# ('\n', tensor(0.7618))
# приостановить
# ('р', tensor(0.3178))
# ('и', tensor(0.1718))
# ('о', tensor(0.0130))
# ('с', tensor(0.0432))
# ('т', tensor(0.5054))
# ('а', tensor(0.1559))
# ('н', tensor(0.0694))
# ('о', tensor(0.0406))
# ('в', tensor(0.1183))
# ('и', tensor(0.1472))
# ('т', tensor(0.3756))
# ('ь', tensor(0.8682))
# ('\n', tensor(0.7952))
# воротца
# ('о', tensor(0.1924))
# ('р', tensor(0.1157))
# ('о', tensor(0.1432))
# ('т', tensor(0.0746))
# ('ц', tensor(0.0048))
# ('а', tensor(0.2821))
# ('\n', tensor(0.3445))
# экстремальный
# ('к', tensor(0.0878))
# ('с', tensor(0.0071))
# ('т', tensor(0.1030))
# ('р', tensor(0.1702))
# ('е', tensor(0.1908))
# ('м', tensor(0.0379))
# ('а', tensor(0.0862))
# ('л', tensor(0.0341))
# ('ь', tensor(0.5428))
# ('н', tensor(0.3509))
# ('ы', tensor(0.7439))
# ('й', tensor(0.9233))
# ('\n', tensor(0.9804))
# исходный
# ('с', tensor(0.0922))
# ('х', tensor(0.0099))
# ('о', tensor(0.1530))
# ('д', tensor(0.0928))
# ('н', tensor(0.0935))
# ('ы', tensor(0.4540))
# ('й', tensor(0.9096))
# ('\n', tensor(0.9544))
# капоэйра
# ('а', tensor(0.3353))
# ('п', tensor(0.0365))
# ('о', tensor(0.1683))
# ('э', tensor(0.0007))
# ('й', tensor(0.0084))
# ('р', tensor(0.0098))
# ('а', tensor(0.2103))
# ('\n', tensor(0.1164))
# беляк
# ('е', tensor(0.2193))
# ('л', tensor(0.1610))
# ('я', tensor(0.0521))
# ('к', tensor(0.0278))
# ('\n', tensor(0.1776))
# самобытный
# ('а', tensor(0.0812))
# ('м', tensor(0.0698))
# ('о', tensor(0.1272))
# ('б', tensor(0.0424))
# ('ы', tensor(0.0101))
# ('т', tensor(0.0581))
# ('н', tensor(0.0161))
# ('ы', tensor(0.3878))
# ('й', tensor(0.9069))
# ('\n', tensor(0.9807))
# отворяться
# ('т', tensor(0.0412))
# ('в', tensor(0.0499))
# ('о', tensor(0.2030))
# ('р', tensor(0.0912))
# ('я', tensor(0.0099))
# ('т', tensor(0.2057))
# ('ь', tensor(0.7353))
# ('с', tensor(0.1644))
# ('я', tensor(0.7951))
# ('\n', tensor(0.8732))
# подвыпить
# ('о', tensor(0.2441))
# ('д', tensor(0.1116))
# ('в', tensor(0.0103))
# ('ы', tensor(0.2106))
# ('п', tensor(0.0014))
# ('и', tensor(0.1483))
# ('т', tensor(0.3573))
# ('ь', tensor(0.8306))
# ('\n', tensor(0.7611))
# повеситься
# ('о', tensor(0.2441))
# ('в', tensor(0.1064))
# ('е', tensor(0.1192))
# ('с', tensor(0.0551))
# ('и', tensor(0.0229))
# ('т', tensor(0.2134))
# ('ь', tensor(0.6466))
# ('с', tensor(0.1518))
# ('я', tensor(0.7853))
# ('\n', tensor(0.8622))
# реабилитировать
# ('е', tensor(0.1883))
# ('а', tensor(0.0016))
# ('б', tensor(0.1490))
# ('и', tensor(0.1793))
# ('л', tensor(0.0761))
# ('и', tensor(0.0757))
# ('т', tensor(0.3743))
# ('и', tensor(0.0372))
# ('р', tensor(0.0469))
# ('о', tensor(0.0809))
# ('в', tensor(0.2623))
# ('а', tensor(0.3136))
# ('т', tensor(0.4202))
# ('ь', tensor(0.8402))
# ('\n', tensor(0.7658))
# ненадёжный
# ('е', tensor(0.2309))
# ('н', tensor(0.0882))
# ('а', tensor(0.0501))
# ('д', tensor(0.0190))
# ('ё', tensor(0.0032))
# ('ж', tensor(0.0298))
# ('н', tensor(0.1985))
# ('ы', tensor(0.6300))
# ('й', tensor(0.9024))
# ('\n', tensor(0.9636))
# полянка
# ('о', tensor(0.2441))
# ('л', tensor(0.1173))
# ('я', tensor(0.0402))
# ('н', tensor(0.1824))
# ('к', tensor(0.0265))
# ('а', tensor(0.4238))
# ('\n', tensor(0.6160))
# начищать
# ('а', tensor(0.1583))
# ('ч', tensor(0.0176))
# ('и', tensor(0.2684))
# ('щ', tensor(0.0024))
# ('а', tensor(0.2362))
# ('т', tensor(0.2108))
# ('ь', tensor(0.8568))
# ('\n', tensor(0.7204))
# алкин
# ('л', tensor(0.1094))
# ('к', tensor(0.0095))
# ('и', tensor(0.2409))
# ('н', tensor(0.0929))
# ('\n', tensor(0.0209))
# луковый
# ('у', tensor(0.0306))
# ('к', tensor(0.0400))
# ('о', tensor(0.1056))
# ('в', tensor(0.1192))
# ('ы', tensor(0.0650))
# ('й', tensor(0.7263))
# ('\n', tensor(0.9356))
# потаскуха
# ('о', tensor(0.2441))
# ('т', tensor(0.0360))
# ('а', tensor(0.0626))
# ('с', tensor(0.0834))
# ('к', tensor(0.1615))
# ('у', tensor(0.0224))
# ('х', tensor(0.0051))
# ('а', tensor(0.1413))
# ('\n', tensor(0.0735))
# трисель
# ('р', tensor(0.2723))
# ('и', tensor(0.1048))
# ('с', tensor(0.1322))
# ('е', tensor(0.0440))
# ('л', tensor(0.1788))
# ('ь', tensor(0.5119))
# ('\n', tensor(0.1550))
# натяжка
# ('а', tensor(0.1583))
# ('т', tensor(0.1492))
# ('я', tensor(0.0041))
# ('ж', tensor(0.0108))
# ('к', tensor(0.0151))
# ('а', tensor(0.3327))
# ('\n', tensor(0.5506))
# крякнуть
# ('р', tensor(0.1347))
# ('я', tensor(0.0124))
# ('к', tensor(0.0301))
# ('н', tensor(0.0407))
# ('у', tensor(0.0370))
# ('т', tensor(0.3064))
# ('ь', tensor(0.5537))
# ('\n', tensor(0.7849))
# выкалять
# ('ы', tensor(0.1032))
# ('к', tensor(0.0187))
# ('а', tensor(0.2447))
# ('л', tensor(0.2297))
# ('я', tensor(0.0528))
# ('т', tensor(0.2643))
# ('ь', tensor(0.7438))
# ('\n', tensor(0.8380))
# осадок
# ('с', tensor(0.0793))
# ('а', tensor(0.0169))
# ('д', tensor(0.0709))
# ('о', tensor(0.2108))
# ('к', tensor(0.0420))
# ('\n', tensor(0.1920))
# классный
# ('л', tensor(0.0320))
# ('а', tensor(0.1947))
# ('с', tensor(0.0544))
# ('с', tensor(0.0270))
# ('н', tensor(0.0147))
# ('ы', tensor(0.1283))
# ('й', tensor(0.9538))
# ('\n', tensor(0.9616))
# ложка
# ('о', tensor(0.2265))
# ('ж', tensor(0.0270))
# ('к', tensor(0.0190))
# ('а', tensor(0.4048))
# ('\n', tensor(0.2510))
# диалект
# ('и', tensor(0.0557))
# ('а', tensor(0.0048))
# ('л', tensor(0.1087))
# ('е', tensor(0.0969))
# ('к', tensor(0.0501))
# ('т', tensor(0.0560))
# ('\n', tensor(0.0199))
# спираль
# ('п', tensor(0.0674))
# ('и', tensor(0.1491))
# ('р', tensor(0.1365))
# ('а', tensor(0.2942))
# ('л', tensor(0.0646))
# ('ь', tensor(0.5842))
# ('\n', tensor(0.1816))
# синеглазый
# ('и', tensor(0.0260))
# ('н', tensor(0.0557))
# ('е', tensor(0.2575))
# ('г', tensor(0.0195))
# ('л', tensor(0.0594))
# ('а', tensor(0.1492))
# ('з', tensor(0.0202))
# ('ы', tensor(0.0115))
# ('й', tensor(0.5370))
# ('\n', tensor(0.9731))
# докладывать
# ('о', tensor(0.2955))
# ('к', tensor(0.0445))
# ('л', tensor(0.0551))
# ('а', tensor(0.2998))
# ('д', tensor(0.0690))
# ('ы', tensor(0.0278))
# ('в', tensor(0.1868))
# ('а', tensor(0.4001))
# ('т', tensor(0.5242))
# ('ь', tensor(0.8863))
# ('\n', tensor(0.8096))
# трахнуться
# ('р', tensor(0.2723))
# ('а', tensor(0.1977))
# ('х', tensor(0.0224))
# ('н', tensor(0.0744))
# ('у', tensor(0.0565))
# ('т', tensor(0.2678))
# ('ь', tensor(0.4977))
# ('с', tensor(0.1717))
# ('я', tensor(0.7966))
# ('\n', tensor(0.8666))
# преодоление
# ('р', tensor(0.3178))
# ('е', tensor(0.1433))
# ('о', tensor(0.0025))
# ('д', tensor(0.1128))
# ('о', tensor(0.1602))
# ('л', tensor(0.0763))
# ('е', tensor(0.0993))
# ('н', tensor(0.3813))
# ('и', tensor(0.1747))
# ('е', tensor(0.0668))
# ('\n', tensor(0.5817))
# сочетаемый
# ('о', tensor(0.1273))
# ('ч', tensor(0.0131))
# ('е', tensor(0.2047))
# ('т', tensor(0.0781))
# ('а', tensor(0.0435))
# ('е', tensor(0.0087))
# ('м', tensor(0.0276))
# ('ы', tensor(0.0594))
# ('й', tensor(0.6069))
# ('\n', tensor(0.9893))
# настойчивый
# ('а', tensor(0.1583))
# ('с', tensor(0.1259))
# ('т', tensor(0.3182))
# ('о', tensor(0.1488))
# ('й', tensor(0.0132))
# ('ч', tensor(0.0059))
# ('и', tensor(0.2367))
# ('в', tensor(0.0693))
# ('ы', tensor(0.1144))
# ('й', tensor(0.9296))
# ('\n', tensor(0.9768))
# иней
# ('н', tensor(0.0669))
# ('е', tensor(0.2553))
# ('й', tensor(0.0067))
# ('\n', tensor(0.4854))
# налеплять
# ('а', tensor(0.1583))
# ('л', tensor(0.0967))
# ('е', tensor(0.1271))
# ('п', tensor(0.0114))
# ('л', tensor(0.0778))
# ('я', tensor(0.0528))
# ('т', tensor(0.1783))
# ('ь', tensor(0.6442))
# ('\n', tensor(0.7757))
# уступ
# ('с', tensor(0.0923))
# ('т', tensor(0.1665))
# ('у', tensor(0.0777))
# ('п', tensor(0.0585))
# ('\n', tensor(0.0454))
# раскрывать
# ('а', tensor(0.3341))
# ('с', tensor(0.1288))
# ('к', tensor(0.1219))
# ('р', tensor(0.0686))
# ('ы', tensor(0.0559))
# ('в', tensor(0.1585))
# ('а', tensor(0.4645))
# ('т', tensor(0.6550))
# ('ь', tensor(0.9039))
# ('\n', tensor(0.7788))
# живописный
# ('и', tensor(0.1063))
# ('в', tensor(0.0758))
# ('о', tensor(0.1914))
# ('п', tensor(0.0334))
# ('и', tensor(0.1755))
# ('с', tensor(0.0514))
# ('н', tensor(0.0342))
# ('ы', tensor(0.2810))
# ('й', tensor(0.9547))
# ('\n', tensor(0.9705))
# винный
# ('и', tensor(0.0445))
# ('н', tensor(0.0504))
# ('н', tensor(0.1049))
# ('ы', tensor(0.5319))
# ('й', tensor(0.8494))
# ('\n', tensor(0.9412))
# дьявол
# ('ь', tensor(0.0007))
# ('я', tensor(0.0033))
# ('в', tensor(0.0312))
# ('о', tensor(0.1485))
# ('л', tensor(0.0607))
# ('\n', tensor(0.0462))
# склонять
# ('к', tensor(0.1142))
# ('л', tensor(0.0511))
# ('о', tensor(0.2142))
# ('н', tensor(0.1033))
# ('я', tensor(0.0031))
# ('т', tensor(0.3181))
# ('ь', tensor(0.8324))
# ('\n', tensor(0.7911))
# издельный
# ('з', tensor(0.1023))
# ('д', tensor(0.0445))
# ('е', tensor(0.1172))
# ('л', tensor(0.1463))
# ('ь', tensor(0.1532))
# ('н', tensor(0.5402))
# ('ы', tensor(0.6796))
# ('й', tensor(0.9038))
# ('\n', tensor(0.9707))
# гуашь
# ('у', tensor(0.0462))
# ('а', tensor(0.0079))
# ('ш', tensor(0.0217))
# ('ь', tensor(0.0003))
# ('\n', tensor(0.8300))
# симфонический
# ('и', tensor(0.0260))
# ('м', tensor(0.0793))
# ('ф', tensor(0.0032))
# ('о', tensor(0.1072))
# ('н', tensor(0.1043))
# ('и', tensor(0.1573))
# ('ч', tensor(0.0283))
# ('е', tensor(0.0800))
# ('с', tensor(0.3068))
# ('к', tensor(0.4250))
# ('и', tensor(0.4321))
# ('й', tensor(0.8388))
# ('\n', tensor(0.9395))
# стандартизировать
# ('т', tensor(0.1537))
# ('а', tensor(0.0701))
# ('н', tensor(0.0324))
# ('д', tensor(0.0174))
# ('а', tensor(0.1492))
# ('р', tensor(0.0361))
# ('т', tensor(0.0242))
# ('и', tensor(0.1891))
# ('з', tensor(0.0269))
# ('и', tensor(0.0978))
# ('р', tensor(0.0159))
# ('о', tensor(0.1274))
# ('в', tensor(0.2928))
# ('а', tensor(0.3490))
# ('т', tensor(0.4287))
# ('ь', tensor(0.8099))
# ('\n', tensor(0.7773))
# разгребать
# ('а', tensor(0.3341))
# ('з', tensor(0.1223))
# ('г', tensor(0.0251))
# ('р', tensor(0.0547))
# ('е', tensor(0.0988))
# ('б', tensor(0.0115))
# ('а', tensor(0.0748))
# ('т', tensor(0.3310))
# ('ь', tensor(0.8568))
# ('\n', tensor(0.8074))
# аварец
# ('в', tensor(0.0310))
# ('а', tensor(0.2268))
# ('р', tensor(0.0756))
# ('е', tensor(0.0885))
# ('ц', tensor(0.0128))
# ('\n', tensor(0.0589))
# паровой
# ('а', tensor(0.1143))
# ('р', tensor(0.1318))
# ('о', tensor(0.1245))
# ('в', tensor(0.1958))
# ('о', tensor(0.1494))
# ('й', tensor(0.0334))
# ('\n', tensor(0.7051))
# швабра
# ('в', tensor(0.0207))
# ('а', tensor(0.3322))
# ('б', tensor(0.0313))
# ('р', tensor(0.0357))
# ('а', tensor(0.3794))
# ('\n', tensor(0.0786))
# рабоче-крестьянский
# ('а', tensor(0.3341))
# ('б', tensor(0.0578))
# ('о', tensor(0.1407))
# ('ч', tensor(0.0395))
# ('е', tensor(0.1048))
# ('-', tensor(0.0020))
# ('к', tensor(0.0406))
# ('р', tensor(0.0314))
# ('е', tensor(0.0608))
# ('с', tensor(0.1829))
# ('т', tensor(0.3162))
# ('ь', tensor(0.1172))
# ('я', tensor(0.0003))
# ('н', tensor(0.0694))
# ('с', tensor(0.0379))
# ('к', tensor(0.2577))
# ('и', tensor(0.1401))
# ('й', tensor(0.8275))
# ('\n', tensor(0.9589))
# текстильный
# ('е', tensor(0.2143))
# ('к', tensor(0.0315))
# ('с', tensor(0.0925))
# ('т', tensor(0.0730))
# ('и', tensor(0.1893))
# ('л', tensor(0.0989))
# ('ь', tensor(0.5749))
# ('н', tensor(0.3052))
# ('ы', tensor(0.6365))
# ('й', tensor(0.9033))
# ('\n', tensor(0.9775))
# покорный
# ('о', tensor(0.2441))
# ('к', tensor(0.0274))
# ('о', tensor(0.1387))
# ('р', tensor(0.1649))
# ('н', tensor(0.0685))
# ('ы', tensor(0.3440))
# ('й', tensor(0.8845))
# ('\n', tensor(0.9633))
# коммунар
# ('о', tensor(0.1939))
# ('м', tensor(0.0717))
# ('м', tensor(0.0602))
# ('у', tensor(0.0714))
# ('н', tensor(0.0712))
# ('а', tensor(0.0725))
# ('р', tensor(0.0133))
# ('\n', tensor(0.1876))
# чёрный кофе
# ('ё', tensor(0.0138))
# ('р', tensor(0.0770))
# ('н', tensor(0.1305))
# ('ы', tensor(0.4687))
# ('й', tensor(0.9280))
# (' ', tensor(0.0430))
# ('к', tensor(0.0737))
# ('о', tensor(0.0972))
# ('ф', tensor(0.0011))
# ('е', tensor(0.0087))
# ('\n', tensor(0.1977))
# трансплантировать
# ('р', tensor(0.2723))
# ('а', tensor(0.1977))
# ('н', tensor(0.0739))
# ('с', tensor(0.0538))
# ('п', tensor(0.0130))
# ('л', tensor(0.0359))
# ('а', tensor(0.1520))
# ('н', tensor(0.3337))
# ('т', tensor(0.0598))
# ('и', tensor(0.0754))
# ('р', tensor(0.0447))
# ('о', tensor(0.0842))
# ('в', tensor(0.2468))
# ('а', tensor(0.3082))
# ('т', tensor(0.3726))
# ('ь', tensor(0.8165))
# ('\n', tensor(0.7568))
# гой
# ('о', tensor(0.2068))
# ('й', tensor(0.0010))
# ('\n', tensor(0.1774))
# подкинуть
# ('о', tensor(0.2441))
# ('д', tensor(0.1116))
# ('к', tensor(0.0405))
# ('и', tensor(0.1800))
# ('н', tensor(0.0508))
# ('у', tensor(0.0112))
# ('т', tensor(0.4619))
# ('ь', tensor(0.7981))
# ('\n', tensor(0.7617))
# фунт стерлингов
# ('у', tensor(0.0304))
# ('н', tensor(0.0301))
# ('т', tensor(0.0195))
# (' ', tensor(2.3596e-05))
# ('с', tensor(0.0174))
# ('т', tensor(0.2145))
# ('е', tensor(0.1442))
# ('р', tensor(0.1333))
# ('л', tensor(0.0146))
# ('и', tensor(0.2327))
# ('н', tensor(0.2709))
# ('г', tensor(0.0037))
# ('о', tensor(0.1299))
# ('в', tensor(0.1434))
# ('\n', tensor(0.0469))
# владикавказ
# ('л', tensor(0.0198))
# ('а', tensor(0.0835))
# ('д', tensor(0.0882))
# ('и', tensor(0.1494))
# ('к', tensor(0.0771))
# ('а', tensor(0.2131))
# ('в', tensor(0.0280))
# ('к', tensor(0.0164))
# ('а', tensor(0.2216))
# ('з', tensor(0.0037))
# ('\n', tensor(0.3879))
# кувыркаться
# ('у', tensor(0.0521))
# ('в', tensor(0.0110))
# ('ы', tensor(0.0756))
# ('р', tensor(0.0081))
# ('к', tensor(0.0118))
# ('а', tensor(0.4110))
# ('т', tensor(0.0936))
# ('ь', tensor(0.6116))
# ('с', tensor(0.0813))
# ('я', tensor(0.7987))
# ('\n', tensor(0.9319))
# реваншизм
# ('е', tensor(0.1883))
# ('в', tensor(0.0593))
# ('а', tensor(0.1894))
# ('н', tensor(0.1105))
# ('ш', tensor(0.0015))
# ('и', tensor(0.1322))
# ('з', tensor(0.0224))
# ('м', tensor(0.0115))
# ('\n', tensor(0.0175))
# разветвлённый
# ('а', tensor(0.3341))
# ('з', tensor(0.1223))
# ('в', tensor(0.0068))
# ('е', tensor(0.0825))
# ('т', tensor(0.1681))
# ('в', tensor(0.0570))
# ('л', tensor(0.0139))
# ('ё', tensor(0.0066))
# ('н', tensor(0.5429))
# ('н', tensor(0.2931))
# ('ы', tensor(0.9180))
# ('й', tensor(0.9701))
# ('\n', tensor(0.9553))
# неприятный
# ('е', tensor(0.2309))
# ('п', tensor(0.0411))
# ('р', tensor(0.2755))
# ('и', tensor(0.2173))
# ('я', tensor(0.0315))
# ('т', tensor(0.1172))
# ('н', tensor(0.0375))
# ('ы', tensor(0.3561))
# ('й', tensor(0.9119))
# ('\n', tensor(0.9786))
# множество
# ('н', tensor(0.0198))
# ('о', tensor(0.1812))
# ('ж', tensor(0.0252))
# ('е', tensor(0.0523))
# ('с', tensor(0.1723))
# ('т', tensor(0.3491))
# ('в', tensor(0.0452))
# ('о', tensor(0.1704))
# ('\n', tensor(0.0479))
# мошонка
# ('о', tensor(0.1739))
# ('ш', tensor(0.0144))
# ('о', tensor(0.1008))
# ('н', tensor(0.0407))
# ('к', tensor(0.0254))
# ('а', tensor(0.4191))
# ('\n', tensor(0.5361))
# замедлить
# ('а', tensor(0.2866))
# ('м', tensor(0.0571))
# ('е', tensor(0.1254))
# ('д', tensor(0.0256))
# ('л', tensor(0.0444))
# ('и', tensor(0.1888))
# ('т', tensor(0.2962))
# ('ь', tensor(0.7344))
# ('\n', tensor(0.7186))
# зачистка
# ('а', tensor(0.2866))
# ('ч', tensor(0.0146))
# ('и', tensor(0.2664))
# ('с', tensor(0.1461))
# ('т', tensor(0.2176))
# ('к', tensor(0.0034))
# ('а', tensor(0.3295))
# ('\n', tensor(0.5701))
# справедливый
# ('п', tensor(0.0674))
# ('р', tensor(0.2894))
# ('а', tensor(0.1429))
# ('в', tensor(0.0660))
# ('е', tensor(0.0763))
# ('д', tensor(0.0345))
# ('л', tensor(0.0180))
# ('и', tensor(0.1805))
# ('в', tensor(0.1163))
# ('ы', tensor(0.2844))
# ('й', tensor(0.8884))
# ('\n', tensor(0.9660))
# ласковый
# ('а', tensor(0.2266))
# ('с', tensor(0.0608))
# ('к', tensor(0.1872))
# ('о', tensor(0.1269))
# ('в', tensor(0.1049))
# ('ы', tensor(0.0851))
# ('й', tensor(0.6473))
# ('\n', tensor(0.9513))
# кинематографический
# ('и', tensor(0.1013))
# ('н', tensor(0.0474))
# ('е', tensor(0.2558))
# ('м', tensor(0.0288))
# ('а', tensor(0.0830))
# ('т', tensor(0.1791))
# ('о', tensor(0.0368))
# ('г', tensor(0.0087))
# ('р', tensor(0.0179))
# ('а', tensor(0.2597))
# ('ф', tensor(0.0069))
# ('и', tensor(0.0402))
# ('ч', tensor(0.0377))
# ('е', tensor(0.1294))
# ('с', tensor(0.2442))
# ('к', tensor(0.4892))
# ('и', tensor(0.3617))
# ('й', tensor(0.8200))
# ('\n', tensor(0.9523))
# вельвет
# ('е', tensor(0.1501))
# ('л', tensor(0.0876))
# ('ь', tensor(0.1571))
# ('в', tensor(0.0111))
# ('е', tensor(0.0390))
# ('т', tensor(0.1875))
# ('\n', tensor(0.0244))
# гейша
# ('е', tensor(0.2521))
# ('й', tensor(0.0007))
# ('ш', tensor(0.0241))
# ('а', tensor(0.1278))
# ('\n', tensor(0.1822))
# пламя
# ('л', tensor(0.0379))
# ('а', tensor(0.1060))
# ('м', tensor(0.0238))
# ('я', tensor(0.0056))
# ('\n', tensor(0.0443))
# итальяшка
# ('т', tensor(0.1103))
# ('а', tensor(0.0514))
# ('л', tensor(0.2102))
# ('ь', tensor(0.3685))
# ('я', tensor(0.0010))
# ('ш', tensor(0.0057))
# ('к', tensor(0.1054))
# ('а', tensor(0.2976))
# ('\n', tensor(0.6991))
# монтаж
# ('о', tensor(0.1739))
# ('н', tensor(0.0613))
# ('т', tensor(0.0356))
# ('а', tensor(0.1214))
# ('ж', tensor(0.0161))
# ('\n', tensor(0.1831))
# вылечивать
# ('ы', tensor(0.1032))
# ('л', tensor(0.0282))
# ('е', tensor(0.1064))
# ('ч', tensor(0.0691))
# ('и', tensor(0.2977))
# ('в', tensor(0.0875))
# ('а', tensor(0.3587))
# ('т', tensor(0.5232))
# ('ь', tensor(0.9261))
# ('\n', tensor(0.7984))
# властный
# ('л', tensor(0.0198))
# ('а', tensor(0.0835))
# ('с', tensor(0.0493))
# ('т', tensor(0.3894))
# ('н', tensor(0.0220))
# ('ы', tensor(0.2533))
# ('й', tensor(0.8978))
# ('\n', tensor(0.9679))
# респектабельный
# ('е', tensor(0.1883))
# ('с', tensor(0.1803))
# ('п', tensor(0.2031))
# ('е', tensor(0.0988))
# ('к', tensor(0.0148))
# ('т', tensor(0.0746))
# ('а', tensor(0.1619))
# ('б', tensor(0.0033))
# ('е', tensor(0.0719))
# ('л', tensor(0.0654))
# ('ь', tensor(0.7994))
# ('н', tensor(0.3446))
# ('ы', tensor(0.7618))
# ('й', tensor(0.9252))
# ('\n', tensor(0.9806))
# отлеплять
# ('т', tensor(0.0412))
# ('л', tensor(0.0572))
# ('е', tensor(0.2720))
# ('п', tensor(0.0249))
# ('л', tensor(0.1136))
# ('я', tensor(0.0659))
# ('т', tensor(0.2073))
# ('ь', tensor(0.6887))
# ('\n', tensor(0.7746))
# модальный глагол
# ('о', tensor(0.1739))
# ('д', tensor(0.0468))
# ('а', tensor(0.0803))
# ('л', tensor(0.1373))
# ('ь', tensor(0.4264))
# ('н', tensor(0.4961))
# ('ы', tensor(0.6536))
# ('й', tensor(0.9143))
# (' ', tensor(0.0207))
# ('г', tensor(0.0027))
# ('л', tensor(0.0108))
# ('а', tensor(0.1177))
# ('г', tensor(0.0351))
# ('о', tensor(0.0416))
# ('л', tensor(0.0580))
# ('\n', tensor(0.2347))
# проинформировать
# ('р', tensor(0.3178))
# ('о', tensor(0.2396))
# ('и', tensor(0.0046))
# ('н', tensor(0.1295))
# ('ф', tensor(0.0027))
# ('о', tensor(0.0639))
# ('р', tensor(0.0371))
# ('м', tensor(0.0128))
# ('и', tensor(0.2064))
# ('р', tensor(0.0280))
# ('о', tensor(0.1188))
# ('в', tensor(0.3111))
# ('а', tensor(0.3614))
# ('т', tensor(0.4520))
# ('ь', tensor(0.8538))
# ('\n', tensor(0.7626))
# расшифровывать
# ('а', tensor(0.3341))
# ('с', tensor(0.1288))
# ('ш', tensor(0.0059))
# ('и', tensor(0.2478))
# ('ф', tensor(0.0030))
# ('р', tensor(0.0542))
# ('о', tensor(0.1098))
# ('в', tensor(0.2546))
# ('ы', tensor(0.1188))
# ('в', tensor(0.0216))
# ('а', tensor(0.3431))
# ('т', tensor(0.5500))
# ('ь', tensor(0.8926))
# ('\n', tensor(0.8151))
# обиженный
# ('б', tensor(0.1613))
# ('и', tensor(0.1170))
# ('ж', tensor(0.0071))
# ('е', tensor(0.1435))
# ('н', tensor(0.1228))
# ('н', tensor(0.2466))
# ('ы', tensor(0.5832))
# ('й', tensor(0.9378))
# ('\n', tensor(0.9672))
# винокурня
# ('и', tensor(0.0445))
# ('н', tensor(0.0504))
# ('о', tensor(0.1362))
# ('к', tensor(0.0497))
# ('у', tensor(0.0125))
# ('р', tensor(0.0540))
# ('н', tensor(0.1045))
# ('я', tensor(0.0232))
# ('\n', tensor(0.2566))
# хирургия
# ('и', tensor(0.0868))
# ('р', tensor(0.1249))
# ('у', tensor(0.0683))
# ('р', tensor(0.0283))
# ('г', tensor(0.0043))
# ('и', tensor(0.2446))
# ('я', tensor(0.0524))
# ('\n', tensor(0.3744))
# видовой
# ('и', tensor(0.0445))
# ('д', tensor(0.0324))
# ('о', tensor(0.2508))
# ('в', tensor(0.1563))
# ('о', tensor(0.1289))
# ('й', tensor(0.0338))
# ('\n', tensor(0.6937))
# документальный
# ('о', tensor(0.2955))
# ('к', tensor(0.0445))
# ('у', tensor(0.0386))
# ('м', tensor(0.0370))
# ('е', tensor(0.0808))
# ('н', tensor(0.2979))
# ('т', tensor(0.0924))
# ('а', tensor(0.0936))
# ('л', tensor(0.0539))
# ('ь', tensor(0.8627))
# ('н', tensor(0.2879))
# ('ы', tensor(0.7287))
# ('й', tensor(0.9296))
# ('\n', tensor(0.9800))
# родимый
# ('о', tensor(0.1981))
# ('д', tensor(0.0895))
# ('и', tensor(0.1101))
# ('м', tensor(0.0385))
# ('ы', tensor(0.0334))
# ('й', tensor(0.5149))
# ('\n', tensor(0.9690))
# кучер
# ('у', tensor(0.0521))
# ('ч', tensor(0.0136))
# ('е', tensor(0.1760))
# ('р', tensor(0.1268))
# ('\n', tensor(0.1013))
# оттопырить
# ('т', tensor(0.0412))
# ('т', tensor(0.0049))
# ('о', tensor(0.1492))
# ('п', tensor(0.0498))
# ('ы', tensor(0.0021))
# ('р', tensor(0.0108))
# ('и', tensor(0.1065))
# ('т', tensor(0.2405))
# ('ь', tensor(0.6237))
# ('\n', tensor(0.7844))
# промазать
# ('р', tensor(0.3178))
# ('о', tensor(0.2396))
# ('м', tensor(0.0682))
# ('а', tensor(0.1583))
# ('з', tensor(0.0175))
# ('а', tensor(0.1525))
# ('т', tensor(0.4449))
# ('ь', tensor(0.7512))
# ('\n', tensor(0.7374))
# чертяга
# ('е', tensor(0.2901))
# ('р', tensor(0.1581))
# ('т', tensor(0.0071))
# ('я', tensor(0.0224))
# ('г', tensor(0.0097))
# ('а', tensor(0.0623))
# ('\n', tensor(0.2136))
# инвентарь
# ('н', tensor(0.0669))
# ('в', tensor(0.0049))
# ('е', tensor(0.2016))
# ('н', tensor(0.1680))
# ('т', tensor(0.0661))
# ('а', tensor(0.1195))
# ('р', tensor(0.0617))
# ('ь', tensor(0.0800))
# ('\n', tensor(0.6941))
# кутить
# ('у', tensor(0.0521))
# ('т', tensor(0.0936))
# ('и', tensor(0.1165))
# ('т', tensor(0.1866))
# ('ь', tensor(0.6354))
# ('\n', tensor(0.7349))
# заковывать
# ('а', tensor(0.2866))
# ('к', tensor(0.0296))
# ('о', tensor(0.1329))
# ('в', tensor(0.0954))
# ('ы', tensor(0.0592))
# ('в', tensor(0.0520))
# ('а', tensor(0.3745))
# ('т', tensor(0.6355))
# ('ь', tensor(0.8996))
# ('\n', tensor(0.8012))
# прополоть
# ('р', tensor(0.3178))
# ('о', tensor(0.2396))
# ('п', tensor(0.0720))
# ('о', tensor(0.2225))
# ('л', tensor(0.1232))
# ('о', tensor(0.0967))
# ('т', tensor(0.2521))
# ('ь', tensor(0.4174))
# ('\n', tensor(0.6248))
# пария
# ('а', tensor(0.1143))
# ('р', tensor(0.1318))
# ('и', tensor(0.1085))
# ('я', tensor(0.0143))
# ('\n', tensor(0.1847))
# грамотный
# ('р', tensor(0.1637))
# ('а', tensor(0.1835))
# ('м', tensor(0.0594))
# ('о', tensor(0.1180))
# ('т', tensor(0.0774))
# ('н', tensor(0.0823))
# ('ы', tensor(0.3759))
# ('й', tensor(0.8933))
# ('\n', tensor(0.9756))
# набитый
# ('а', tensor(0.1583))
# ('б', tensor(0.0292))
# ('и', tensor(0.1545))
# ('т', tensor(0.1866))
# ('ы', tensor(0.0096))
# ('й', tensor(0.4635))
# ('\n', tensor(0.9577))
# потоп
# ('о', tensor(0.2441))
# ('т', tensor(0.0360))
# ('о', tensor(0.1246))
# ('п', tensor(0.0338))
# ('\n', tensor(0.0471))
# кварц
# ('в', tensor(0.0133))
# ('а', tensor(0.3265))
# ('р', tensor(0.0447))
# ('ц', tensor(0.0035))
# ('\n', tensor(0.0063))
# воспевать
# ('о', tensor(0.1924))
# ('с', tensor(0.0860))
# ('п', tensor(0.0717))
# ('е', tensor(0.1050))
# ('в', tensor(0.0989))
# ('а', tensor(0.2712))
# ('т', tensor(0.5626))
# ('ь', tensor(0.8429))
# ('\n', tensor(0.7456))
# разрешённый
# ('а', tensor(0.3341))
# ('з', tensor(0.1223))
# ('р', tensor(0.0086))
# ('е', tensor(0.1009))
# ('ш', tensor(0.0327))
# ('ё', tensor(0.0056))
# ('н', tensor(0.2308))
# ('н', tensor(0.2966))
# ('ы', tensor(0.8192))
# ('й', tensor(0.9363))
# ('\n', tensor(0.9608))
# синод
# ('и', tensor(0.0260))
# ('н', tensor(0.0557))
# ('о', tensor(0.1724))
# ('д', tensor(0.0357))
# ('\n', tensor(0.1340))
# разъяснять
# ('а', tensor(0.3341))
# ('з', tensor(0.1223))
# ('ъ', tensor(0.0016))
# ('я', tensor(0.0017))
# ('с', tensor(0.1009))
# ('н', tensor(0.0335))
# ('я', tensor(0.0140))
# ('т', tensor(0.1862))
# ('ь', tensor(0.7423))
# ('\n', tensor(0.8499))
# волнистый
# ('о', tensor(0.1924))
# ('л', tensor(0.0638))
# ('н', tensor(0.0504))
# ('и', tensor(0.1004))
# ('с', tensor(0.0677))
# ('т', tensor(0.4770))
# ('ы', tensor(0.0296))
# ('й', tensor(0.7531))
# ('\n', tensor(0.9495))
# аристарх
# ('р', tensor(0.1217))
# ('и', tensor(0.1173))
# ('с', tensor(0.0929))
# ('т', tensor(0.2078))
# ('а', tensor(0.1016))
# ('р', tensor(0.0859))
# ('х', tensor(0.0009))
# ('\n', tensor(0.0005))
# трёхэтажное слово
# ('р', tensor(0.2723))
# ('ё', tensor(0.0089))
# ('х', tensor(0.0189))
# ('э', tensor(0.0015))
# ('т', tensor(0.3199))
# ('а', tensor(0.0816))
# ('ж', tensor(0.0121))
# ('н', tensor(0.1473))
# ('о', tensor(0.0574))
# ('е', tensor(0.0302))
# (' ', tensor(0.1596))
# ('с', tensor(0.0261))
# ('л', tensor(0.0466))
# ('о', tensor(0.1703))
# ('в', tensor(0.1738))
# ('о', tensor(0.1076))
# ('\n', tensor(0.0283))
# абордажный
# ('б', tensor(0.1092))
# ('о', tensor(0.1107))
# ('р', tensor(0.1223))
# ('д', tensor(0.0384))
# ('а', tensor(0.1828))
# ('ж', tensor(0.0144))
# ('н', tensor(0.1197))
# ('ы', tensor(0.4921))
# ('й', tensor(0.8751))
# ('\n', tensor(0.9748))
# лестничный
# ('е', tensor(0.2491))
# ('с', tensor(0.0878))
# ('т', tensor(0.2373))
# ('н', tensor(0.0184))
# ('и', tensor(0.1129))
# ('ч', tensor(0.0334))
# ('н', tensor(0.0698))
# ('ы', tensor(0.6651))
# ('й', tensor(0.8639))
# ('\n', tensor(0.9718))
# грязнуля
# ('р', tensor(0.1637))
# ('я', tensor(0.0248))
# ('з', tensor(0.0931))
# ('н', tensor(0.1215))
# ('у', tensor(0.0369))
# ('л', tensor(0.0353))
# ('я', tensor(0.0148))
# ('\n', tensor(0.0169))
# цепенеть
# ('е', tensor(0.2024))
# ('п', tensor(0.0414))
# ('е', tensor(0.1032))
# ('н', tensor(0.1982))
# ('е', tensor(0.1303))
# ('т', tensor(0.1047))
# ('ь', tensor(0.5218))
# ('\n', tensor(0.7818))
# кинофестиваль
# ('и', tensor(0.1013))
# ('н', tensor(0.0474))
# ('о', tensor(0.1298))
# ('ф', tensor(0.0054))
# ('е', tensor(0.0068))
# ('с', tensor(0.1659))
# ('т', tensor(0.3625))
# ('и', tensor(0.2876))
# ('в', tensor(0.1112))
# ('а', tensor(0.2817))
# ('л', tensor(0.0357))
# ('ь', tensor(0.8320))
# ('\n', tensor(0.3864))
# неосознанный
# ('е', tensor(0.2309))
# ('о', tensor(0.0035))
# ('с', tensor(0.1255))
# ('о', tensor(0.0412))
# ('з', tensor(0.0207))
# ('н', tensor(0.0961))
# ('а', tensor(0.1430))
# ('н', tensor(0.1459))
# ('н', tensor(0.2178))
# ('ы', tensor(0.7543))
# ('й', tensor(0.9314))
# ('\n', tensor(0.9712))
# пешеходный переход
# ('е', tensor(0.1352))
# ('ш', tensor(0.0093))
# ('е', tensor(0.1324))
# ('х', tensor(0.0095))
# ('о', tensor(0.0800))
# ('д', tensor(0.0533))
# ('н', tensor(0.0850))
# ('ы', tensor(0.5274))
# ('й', tensor(0.9433))
# (' ', tensor(0.0219))
# ('п', tensor(0.0592))
# ('е', tensor(0.0680))
# ('р', tensor(0.1554))
# ('е', tensor(0.1445))
# ('х', tensor(0.0027))
# ('о', tensor(0.0685))
# ('д', tensor(0.0291))
# ('\n', tensor(0.3186))
# ревнивый
# ('е', tensor(0.1883))
# ('в', tensor(0.0593))
# ('н', tensor(0.0595))
# ('и', tensor(0.2185))
# ('в', tensor(0.0786))
# ('ы', tensor(0.1869))
# ('й', tensor(0.8284))
# ('\n', tensor(0.9412))
# мошна
# ('о', tensor(0.1739))
# ('ш', tensor(0.0144))
# ('н', tensor(0.0366))
# ('а', tensor(0.1942))
# ('\n', tensor(0.0798))
# райком
# ('а', tensor(0.3341))
# ('й', tensor(0.0002))
# ('к', tensor(0.0156))
# ('о', tensor(0.1285))
# ('м', tensor(0.0459))
# ('\n', tensor(0.1234))
# выносливый
# ('ы', tensor(0.1032))
# ('н', tensor(0.0194))
# ('о', tensor(0.0747))
# ('с', tensor(0.0705))
# ('л', tensor(0.0481))
# ('и', tensor(0.1704))
# ('в', tensor(0.1254))
# ('ы', tensor(0.1689))
# ('й', tensor(0.7908))
# ('\n', tensor(0.9598))
# выбыть
# ('ы', tensor(0.1032))
# ('б', tensor(0.0244))
# ('ы', tensor(0.0130))
# ('т', tensor(0.0906))
# ('ь', tensor(0.5595))
# ('\n', tensor(0.6944))
# беззаботный
# ('е', tensor(0.2193))
# ('з', tensor(0.0572))
# ('з', tensor(0.0054))
# ('а', tensor(0.1750))
# ('б', tensor(0.0401))
# ('о', tensor(0.1051))
# ('т', tensor(0.1483))
# ('н', tensor(0.0724))
# ('ы', tensor(0.4138))
# ('й', tensor(0.8886))
# ('\n', tensor(0.9797))
# резервный
# ('е', tensor(0.1883))
# ('з', tensor(0.1041))
# ('е', tensor(0.1288))
# ('р', tensor(0.0619))
# ('в', tensor(0.0257))
# ('н', tensor(0.0093))
# ('ы', tensor(0.2259))
# ('й', tensor(0.9044))
# ('\n', tensor(0.9623))
# сменный
# ('м', tensor(0.0229))
# ('е', tensor(0.1918))
# ('н', tensor(0.1286))
# ('н', tensor(0.1781))
# ('ы', tensor(0.4840))
# ('й', tensor(0.9047))
# ('\n', tensor(0.9509))
# отклонить
# ('т', tensor(0.0412))
# ('к', tensor(0.0160))
# ('л', tensor(0.0612))
# ('о', tensor(0.1599))
# ('н', tensor(0.1283))
# ('и', tensor(0.1525))
# ('т', tensor(0.3617))
# ('ь', tensor(0.8030))
# ('\n', tensor(0.7775))
# колебать
# ('о', tensor(0.1939))
# ('л', tensor(0.1704))
# ('е', tensor(0.1735))
# ('б', tensor(0.0224))
# ('а', tensor(0.0532))
# ('т', tensor(0.3315))
# ('ь', tensor(0.7823))
# ('\n', tensor(0.7833))
# модернизм
# ('о', tensor(0.1739))
# ('д', tensor(0.0468))
# ('е', tensor(0.0729))
# ('р', tensor(0.1465))
# ('н', tensor(0.0900))
# ('и', tensor(0.2192))
# ('з', tensor(0.0297))
# ('м', tensor(0.0139))
# ('\n', tensor(0.0155))
# диагност
# ('и', tensor(0.0557))
# ('а', tensor(0.0048))
# ('г', tensor(0.0652))
# ('н', tensor(0.0512))
# ('о', tensor(0.1431))
# ('с', tensor(0.0801))
# ('т', tensor(0.4355))
# ('\n', tensor(0.0438))
# пленять
# ('л', tensor(0.0379))
# ('е', tensor(0.1930))
# ('н', tensor(0.2127))
# ('я', tensor(0.0035))
# ('т', tensor(0.2020))
# ('ь', tensor(0.6917))
# ('\n', tensor(0.7624))
# порицать
# ('о', tensor(0.2441))
# ('р', tensor(0.1525))
# ('и', tensor(0.0913))
# ('ц', tensor(0.0139))
# ('а', tensor(0.2257))
# ('т', tensor(0.1577))
# ('ь', tensor(0.6770))
# ('\n', tensor(0.7553))
# сочленение
# ('о', tensor(0.1273))
# ('ч', tensor(0.0131))
# ('л', tensor(0.0071))
# ('е', tensor(0.1912))
# ('н', tensor(0.3727))
# ('е', tensor(0.0756))
# ('н', tensor(0.2333))
# ('и', tensor(0.1345))
# ('е', tensor(0.0635))
# ('\n', tensor(0.5673))
# хромой
# ('р', tensor(0.0183))
# ('о', tensor(0.1940))
# ('м', tensor(0.0599))
# ('о', tensor(0.1195))
# ('й', tensor(0.0052))
# ('\n', tensor(0.7743))
# магний
# ('а', tensor(0.2261))
# ('г', tensor(0.0663))
# ('н', tensor(0.0412))
# ('и', tensor(0.1408))
# ('й', tensor(0.1314))
# ('\n', tensor(0.8853))
# спутниковый
# ('п', tensor(0.0674))
# ('у', tensor(0.0554))
# ('т', tensor(0.1403))
# ('н', tensor(0.0994))
# ('и', tensor(0.1033))
# ('к', tensor(0.0969))
# ('о', tensor(0.0543))
# ('в', tensor(0.0839))
# ('ы', tensor(0.1622))
# ('й', tensor(0.8840))
# ('\n', tensor(0.9627))
# ответственность
# ('т', tensor(0.0412))
# ('в', tensor(0.0499))
# ('е', tensor(0.1762))
# ('т', tensor(0.0877))
# ('с', tensor(0.0371))
# ('т', tensor(0.2272))
# ('в', tensor(0.0353))
# ('е', tensor(0.1311))
# ('н', tensor(0.3288))
# ('н', tensor(0.2560))
# ('о', tensor(0.0329))
# ('с', tensor(0.0864))
# ('т', tensor(0.2776))
# ('ь', tensor(0.2778))
# ('\n', tensor(0.7602))
# пористый
# ('о', tensor(0.2441))
# ('р', tensor(0.1525))
# ('и', tensor(0.0913))
# ('с', tensor(0.0746))
# ('т', tensor(0.2931))
# ('ы', tensor(0.0269))
# ('й', tensor(0.6198))
# ('\n', tensor(0.9461))
# сопеть
# ('о', tensor(0.1273))
# ('п', tensor(0.0474))
# ('е', tensor(0.0806))
# ('т', tensor(0.0630))
# ('ь', tensor(0.3270))
# ('\n', tensor(0.5704))
# затрудняться
# ('а', tensor(0.2866))
# ('т', tensor(0.1369))
# ('р', tensor(0.1973))
# ('у', tensor(0.0674))
# ('д', tensor(0.0483))
# ('н', tensor(0.1429))
# ('я', tensor(0.0464))
# ('т', tensor(0.1376))
# ('ь', tensor(0.8331))
# ('с', tensor(0.1253))
# ('я', tensor(0.8259))
# ('\n', tensor(0.9128))
# киностудия
# ('и', tensor(0.1013))
# ('н', tensor(0.0474))
# ('о', tensor(0.1298))
# ('с', tensor(0.0955))
# ('т', tensor(0.3579))
# ('у', tensor(0.0266))
# ('д', tensor(0.0282))
# ('и', tensor(0.1978))
# ('я', tensor(0.1177))
# ('\n', tensor(0.7005))
# опешить
# ('п', tensor(0.0447))
# ('е', tensor(0.0810))
# ('ш', tensor(0.0149))
# ('и', tensor(0.1084))
# ('т', tensor(0.1667))
# ('ь', tensor(0.3976))
# ('\n', tensor(0.7440))
# милорд
# ('и', tensor(0.0986))
# ('л', tensor(0.0382))
# ('о', tensor(0.2580))
# ('р', tensor(0.0833))
# ('д', tensor(0.0218))
# ('\n', tensor(0.0054))
# неразумный
# ('е', tensor(0.2309))
# ('р', tensor(0.1342))
# ('а', tensor(0.1221))
# ('з', tensor(0.0394))
# ('у', tensor(0.0162))
# ('м', tensor(0.0379))
# ('н', tensor(0.1186))
# ('ы', tensor(0.6482))
# ('й', tensor(0.9250))
# ('\n', tensor(0.9670))
# неудобный
# ('е', tensor(0.2309))
# ('у', tensor(0.0027))
# ('д', tensor(0.0699))
# ('о', tensor(0.1544))
# ('б', tensor(0.0290))
# ('н', tensor(0.1218))
# ('ы', tensor(0.5103))
# ('й', tensor(0.8362))
# ('\n', tensor(0.9690))
# отстранить
# ('т', tensor(0.0412))
# ('с', tensor(0.0352))
# ('т', tensor(0.1353))
# ('р', tensor(0.1677))
# ('а', tensor(0.2544))
# ('н', tensor(0.1467))
# ('и', tensor(0.1667))
# ('т', tensor(0.2896))
# ('ь', tensor(0.7637))
# ('\n', tensor(0.8096))
# ссора
# ('с', tensor(0.0235))
# ('о', tensor(0.1068))
# ('р', tensor(0.1231))
# ('а', tensor(0.2491))
# ('\n', tensor(0.0107))
# блогер
# ('л', tensor(0.0157))
# ('о', tensor(0.2204))
# ('г', tensor(0.1007))
# ('е', tensor(0.0943))
# ('р', tensor(0.1526))
# ('\n', tensor(0.0472))
# созвездие
# ('о', tensor(0.1273))
# ('з', tensor(0.0508))
# ('в', tensor(0.0140))
# ('е', tensor(0.0870))
# ('з', tensor(0.0499))
# ('д', tensor(0.0880))
# ('и', tensor(0.2375))
# ('е', tensor(0.0297))
# ('\n', tensor(0.2908))
# суммарный
# ('у', tensor(0.0311))
# ('м', tensor(0.0811))
# ('м', tensor(0.0243))
# ('а', tensor(0.1866))
# ('р', tensor(0.0469))
# ('н', tensor(0.1128))
# ('ы', tensor(0.5613))
# ('й', tensor(0.9559))
# ('\n', tensor(0.9667))
# агглютинативный
# ('г', tensor(0.0339))
# ('г', tensor(0.0050))
# ('л', tensor(0.0207))
# ('ю', tensor(0.0186))
# ('т', tensor(0.2291))
# ('и', tensor(0.2046))
# ('н', tensor(0.0703))
# ('а', tensor(0.1107))
# ('т', tensor(0.2786))
# ('и', tensor(0.0134))
# ('в', tensor(0.0655))
# ('н', tensor(0.0365))
# ('ы', tensor(0.5143))
# ('й', tensor(0.9417))
# ('\n', tensor(0.9792))
# променивать
# ('р', tensor(0.3178))
# ('о', tensor(0.2396))
# ('м', tensor(0.0682))
# ('е', tensor(0.1003))
# ('н', tensor(0.2260))
# ('и', tensor(0.1593))
# ('в', tensor(0.0815))
# ('а', tensor(0.3271))
# ('т', tensor(0.5182))
# ('ь', tensor(0.9074))
# ('\n', tensor(0.7692))
# дирижабль
# ('и', tensor(0.0557))
# ('р', tensor(0.1056))
# ('и', tensor(0.0941))
# ('ж', tensor(0.0115))
# ('а', tensor(0.2128))
# ('б', tensor(0.0141))
# ('л', tensor(0.0178))
# ('ь', tensor(0.0175))
# ('\n', tensor(0.4693))
# прибивать
# ('р', tensor(0.3178))
# ('и', tensor(0.1718))
# ('б', tensor(0.0210))
# ('и', tensor(0.1281))
# ('в', tensor(0.0849))
# ('а', tensor(0.3641))
# ('т', tensor(0.5768))
# ('ь', tensor(0.8964))
# ('\n', tensor(0.7262))
# подвинуть
# ...
# ('ч', tensor(0.0302))
# ('е', tensor(0.1658))
# ('с', tensor(0.2776))
# ('к', tensor(0.4035))
# ('и', tensor(0.4487))
# ('й', tensor(0.8476))
# ('\n', tensor(0.9408))
# бережок
# ('е', tensor(0.2193))
# ('р', tensor(0.1893))
# ('е', tensor(0.1463))
# ('ж', tensor(0.0242))
# ('о', tensor(0.0555))
# ('к', tensor(0.0266))
# ('\n', tensor(0.2138))
# выключение
# ('ы', tensor(0.1032))
# ('к', tensor(0.0187))
# ('л', tensor(0.0533))
# ('ю', tensor(0.0353))
# ('ч', tensor(0.0344))
# ('е', tensor(0.1215))
# ('н', tensor(0.1464))
# ('и', tensor(0.1686))
# ('е', tensor(0.0460))
# ('\n', tensor(0.7190))
# сатирический
# ('а', tensor(0.0812))
# ('т', tensor(0.0898))
# ('и', tensor(0.0496))
# ('р', tensor(0.1119))
# ('и', tensor(0.1433))
# ('ч', tensor(0.0446))
# ('е', tensor(0.1435))
# ('с', tensor(0.2759))
# ('к', tensor(0.3989))
# ('и', tensor(0.4567))
# ('й', tensor(0.8256))
# ('\n', tensor(0.9371))
# мальтийский
# ('а', tensor(0.2261))
# ('л', tensor(0.0820))
# ('ь', tensor(0.0882))
# ('т', tensor(0.0138))
# ('и', tensor(0.0901))
# ('й', tensor(0.0290))
# ('с', tensor(0.0099))
# ('к', tensor(0.1666))
# ('и', tensor(0.3059))
# ('й', tensor(0.7356))
# ('\n', tensor(0.9442))
# беспочвенный
# ('е', tensor(0.2193))
# ('с', tensor(0.1771))
# ('п', tensor(0.1600))
# ('о', tensor(0.2222))
# ('ч', tensor(0.0246))
# ('в', tensor(0.0043))
# ('е', tensor(0.0681))
# ('н', tensor(0.3033))
# ('н', tensor(0.2793))
# ('ы', tensor(0.7403))
# ('й', tensor(0.9517))
# ('\n', tensor(0.9691))
# февральский
# ('е', tensor(0.0977))
# ('в', tensor(0.0207))
# ('р', tensor(0.0273))
# ('а', tensor(0.1501))
# ('л', tensor(0.0456))
# ('ь', tensor(0.4847))
# ('с', tensor(0.1948))
# ('к', tensor(0.1469))
# ('и', tensor(0.3541))
# ('й', tensor(0.8747))
# ('\n', tensor(0.9546))
# вентиляционный
# ('е', tensor(0.1501))
# ('н', tensor(0.0920))
# ('т', tensor(0.0429))
# ('и', tensor(0.0785))
# ('л', tensor(0.0787))
# ('я', tensor(0.0233))
# ('ц', tensor(0.0257))
# ('и', tensor(0.4144))
# ('о', tensor(0.0266))
# ('н', tensor(0.0424))
# ('н', tensor(0.2000))
# ('ы', tensor(0.6098))
# ('й', tensor(0.9173))
# ('\n', tensor(0.9754))
# собранный
# ('о', tensor(0.1273))
# ('б', tensor(0.0870))
# ('р', tensor(0.0780))
# ('а', tensor(0.3775))
# ('н', tensor(0.0834))
# ('н', tensor(0.2667))
# ('ы', tensor(0.7088))
# ('й', tensor(0.9110))
# ('\n', tensor(0.9643))
# сиверко
# ('и', tensor(0.0260))
# ('в', tensor(0.0916))
# ('е', tensor(0.1869))
# ('р', tensor(0.1637))
# ('к', tensor(0.0398))
# ('о', tensor(0.0855))
# ('\n', tensor(0.1507))
# тога
# ('о', tensor(0.1597))
# ('г', tensor(0.0265))
# ('а', tensor(0.0860))
# ('\n', tensor(0.0312))
# перекатываться
# ('е', tensor(0.1352))
# ('р', tensor(0.2275))
# ('е', tensor(0.1681))
# ('к', tensor(0.0372))
# ('а', tensor(0.1532))
# ('т', tensor(0.1582))
# ('ы', tensor(0.0080))
# ('в', tensor(0.1518))
# ('а', tensor(0.3449))
# ('т', tensor(0.4720))
# ('ь', tensor(0.8726))
# ('с', tensor(0.1115))
# ('я', tensor(0.8789))
# ('\n', tensor(0.9447))
# окарина
# ('к', tensor(0.0180))
# ('а', tensor(0.1666))
# ('р', tensor(0.1690))
# ('и', tensor(0.1267))
# ('н', tensor(0.0867))
# ('а', tensor(0.1364))
# ('\n', tensor(0.1280))
# выруский
# ('ы', tensor(0.1032))
# ('р', tensor(0.0264))
# ('у', tensor(0.0665))
# ('с', tensor(0.0681))
# ('к', tensor(0.1557))
# ('и', tensor(0.3128))
# ('й', tensor(0.6056))
# ('\n', tensor(0.8773))
# составной
# ('о', tensor(0.1273))
# ('с', tensor(0.0372))
# ('т', tensor(0.2809))
# ('а', tensor(0.1403))
# ('в', tensor(0.0541))
# ('н', tensor(0.1063))
# ('о', tensor(0.0352))
# ('й', tensor(0.1046))
# ('\n', tensor(0.9028))
# вышестоящий
# ('ы', tensor(0.1032))
# ('ш', tensor(0.0096))
# ('е', tensor(0.0698))
# ('с', tensor(0.0507))
# ('т', tensor(0.3549))
# ('о', tensor(0.1223))
# ('я', tensor(0.0066))
# ('щ', tensor(0.0035))
# ('и', tensor(0.3633))
# ('й', tensor(0.2468))
# ('\n', tensor(0.9479))
# оттаять
# ('т', tensor(0.0412))
# ('т', tensor(0.0049))
# ('а', tensor(0.0692))
# ('я', tensor(0.0036))
# ('т', tensor(0.1089))
# ('ь', tensor(0.5032))
# ('\n', tensor(0.8456))
# затаптывать
# ('а', tensor(0.2866))
# ('т', tensor(0.1369))
# ('а', tensor(0.0550))
# ('п', tensor(0.0180))
# ('т', tensor(0.0058))
# ('ы', tensor(0.0378))
# ('в', tensor(0.1591))
# ('а', tensor(0.3734))
# ('т', tensor(0.4968))
# ('ь', tensor(0.8713))
# ('\n', tensor(0.8155))
# вскарабкиваться
# ('с', tensor(0.0036))
# ('к', tensor(0.1639))
# ('а', tensor(0.1743))
# ('р', tensor(0.1304))
# ('а', tensor(0.2700))
# ('б', tensor(0.0188))
# ('к', tensor(0.0102))
# ('и', tensor(0.2515))
# ('в', tensor(0.0415))
# ('а', tensor(0.2750))
# ('т', tensor(0.4183))
# ('ь', tensor(0.9087))
# ('с', tensor(0.1087))
# ('я', tensor(0.8676))
# ('\n', tensor(0.9378))
# карибский
# ('а', tensor(0.3353))
# ('р', tensor(0.1726))
# ('и', tensor(0.1143))
# ('б', tensor(0.0130))
# ('с', tensor(0.0124))
# ('к', tensor(0.1371))
# ('и', tensor(0.3224))
# ('й', tensor(0.6540))
# ('\n', tensor(0.9297))
# рассекать
# ('а', tensor(0.3341))
# ('с', tensor(0.1288))
# ('с', tensor(0.0224))
# ('е', tensor(0.0449))
# ('к', tensor(0.0097))
# ('а', tensor(0.1780))
# ('т', tensor(0.1937))
# ('ь', tensor(0.6571))
# ('\n', tensor(0.8386))
# смиренный
# ('м', tensor(0.0229))
# ('и', tensor(0.2802))
# ('р', tensor(0.0898))
# ('е', tensor(0.1212))
# ('н', tensor(0.1093))
# ('н', tensor(0.2520))
# ('ы', tensor(0.6195))
# ('й', tensor(0.9268))
# ('\n', tensor(0.9609))
# исцелять
# ('с', tensor(0.0922))
# ('ц', tensor(0.0050))
# ('е', tensor(0.1372))
# ('л', tensor(0.1087))
# ('я', tensor(0.0341))
# ('т', tensor(0.2270))
# ('ь', tensor(0.6770))
# ('\n', tensor(0.7832))
# завлечь
# ('а', tensor(0.2866))
# ('в', tensor(0.0476))
# ('л', tensor(0.0518))
# ('е', tensor(0.2881))
# ('ч', tensor(0.0523))
# ('ь', tensor(0.0500))
# ('\n', tensor(0.4658))
# отвергать
# ('т', tensor(0.0412))
# ('в', tensor(0.0499))
# ('е', tensor(0.1762))
# ('р', tensor(0.1350))
# ('г', tensor(0.0113))
# ('а', tensor(0.1906))
# ('т', tensor(0.2039))
# ('ь', tensor(0.7104))
# ('\n', tensor(0.7399))
# алармист
# ('л', tensor(0.1094))
# ('а', tensor(0.1223))
# ('р', tensor(0.0655))
# ('м', tensor(0.0152))
# ('и', tensor(0.2235))
# ('с', tensor(0.0316))
# ('т', tensor(0.4340))
# ('\n', tensor(0.0505))
# вырезывать
# ('ы', tensor(0.1032))
# ('р', tensor(0.0264))
# ('е', tensor(0.0814))
# ('з', tensor(0.0465))
# ('ы', tensor(0.0009))
# ('в', tensor(0.2786))
# ('а', tensor(0.5420))
# ('т', tensor(0.6010))
# ('ь', tensor(0.8443))
# ('\n', tensor(0.7853))
# выгода
# ('ы', tensor(0.1032))
# ('г', tensor(0.0277))
# ('о', tensor(0.1002))
# ('д', tensor(0.0383))
# ('а', tensor(0.0974))
# ('\n', tensor(0.1160))
# кондиционер
# ('о', tensor(0.1939))
# ('н', tensor(0.0346))
# ('д', tensor(0.0374))
# ('и', tensor(0.0484))
# ('ц', tensor(0.0185))
# ('и', tensor(0.3016))
# ('о', tensor(0.0251))
# ('н', tensor(0.0588))
# ('е', tensor(0.0695))
# ('р', tensor(0.0610))
# ('\n', tensor(0.1529))
# антимонопольный
# ('н', tensor(0.0729))
# ('т', tensor(0.0486))
# ('и', tensor(0.0611))
# ('м', tensor(0.0169))
# ('о', tensor(0.1065))
# ('н', tensor(0.1397))
# ('о', tensor(0.0770))
# ('п', tensor(0.0113))
# ('о', tensor(0.1240))
# ('л', tensor(0.0989))
# ('ь', tensor(0.3448))
# ('н', tensor(0.3960))
# ('ы', tensor(0.6417))
# ('й', tensor(0.9064))
# ('\n', tensor(0.9785))
# годичный
# ('о', tensor(0.2068))
# ('д', tensor(0.0613))
# ('и', tensor(0.1065))
# ('ч', tensor(0.0491))
# ('н', tensor(0.0566))
# ('ы', tensor(0.5561))
# ('й', tensor(0.7855))
# ('\n', tensor(0.9707))
# гимн
# ('и', tensor(0.0689))
# ('м', tensor(0.0446))
# ('н', tensor(0.0476))
# ('\n', tensor(0.0010))
# различать
# ('а', tensor(0.3341))
# ('з', tensor(0.1223))
# ('л', tensor(0.0336))
# ('и', tensor(0.1492))
# ('ч', tensor(0.0678))
# ('а', tensor(0.2336))
# ('т', tensor(0.4271))
# ('ь', tensor(0.8062))
# ('\n', tensor(0.7943))
# попович
# ('о', tensor(0.2441))
# ('п', tensor(0.0395))
# ('о', tensor(0.2050))
# ('в', tensor(0.1604))
# ('и', tensor(0.1045))
# ('ч', tensor(0.0372))
# ('\n', tensor(0.1177))
# произвол
# ('р', tensor(0.3178))
# ('о', tensor(0.2396))
# ('и', tensor(0.0046))
# ('з', tensor(0.0689))
# ('в', tensor(0.0106))
# ('о', tensor(0.1443))
# ('л', tensor(0.0461))
# ('\n', tensor(0.0204))
# мужская
# ('у', tensor(0.0673))
# ('ж', tensor(0.0499))
# ('с', tensor(0.0209))
# ('к', tensor(0.1141))
# ('а', tensor(0.3437))
# ('я', tensor(0.0061))
# ('\n', tensor(0.3027))
# всадить
# ('с', tensor(0.0036))
# ('а', tensor(0.0293))
# ('д', tensor(0.0712))
# ('и', tensor(0.0749))
# ('т', tensor(0.1930))
# ('ь', tensor(0.4760))
# ('\n', tensor(0.7503))
# хоронить
# ('о', tensor(0.1548))
# ('р', tensor(0.1521))
# ('о', tensor(0.1677))
# ('н', tensor(0.0374))
# ('и', tensor(0.1711))
# ('т', tensor(0.3576))
# ('ь', tensor(0.7207))
# ('\n', tensor(0.6939))
# соотноситься
# ('о', tensor(0.1273))
# ('о', tensor(0.0067))
# ('т', tensor(0.0509))
# ('н', tensor(0.0725))
# ('о', tensor(0.1251))
# ('с', tensor(0.0675))
# ('и', tensor(0.0274))
# ('т', tensor(0.2825))
# ('ь', tensor(0.7938))
# ('с', tensor(0.1441))
# ('я', tensor(0.7939))
# ('\n', tensor(0.8827))
# стопарик
# ('т', tensor(0.1537))
# ('о', tensor(0.1433))
# ('п', tensor(0.0603))
# ('а', tensor(0.0933))
# ('р', tensor(0.0649))
# ('и', tensor(0.1525))
# ('к', tensor(0.0619))
# ('\n', tensor(0.2165))
# кухарка
# ('у', tensor(0.0521))
# ('х', tensor(0.0155))
# ('а', tensor(0.1082))
# ('р', tensor(0.0938))
# ('к', tensor(0.0280))
# ('а', tensor(0.3389))
# ('\n', tensor(0.4110))
# полимерный
# ('о', tensor(0.2441))
# ('л', tensor(0.1173))
# ('и', tensor(0.1146))
# ('м', tensor(0.0175))
# ('е', tensor(0.1214))
# ('р', tensor(0.0695))
# ('н', tensor(0.1050))
# ('ы', tensor(0.4821))
# ('й', tensor(0.9651))
# ('\n', tensor(0.9650))
# сточный
# ('т', tensor(0.1537))
# ('о', tensor(0.1433))
# ('ч', tensor(0.0288))
# ('н', tensor(0.1233))
# ('ы', tensor(0.5287))
# ('й', tensor(0.7233))
# ('\n', tensor(0.9610))
# система
# ('и', tensor(0.0260))
# ('с', tensor(0.0447))
# ('т', tensor(0.2467))
# ('е', tensor(0.1349))
# ('м', tensor(0.0125))
# ('а', tensor(0.0934))
# ('\n', tensor(0.0769))
# разминать
# ('а', tensor(0.3341))
# ('з', tensor(0.1223))
# ('м', tensor(0.0590))
# ('и', tensor(0.2141))
# ('н', tensor(0.1609))
# ('а', tensor(0.1209))
# ('т', tensor(0.4131))
# ('ь', tensor(0.8589))
# ('\n', tensor(0.7662))
# баритон
# ('а', tensor(0.1437))
# ('р', tensor(0.1091))
# ('и', tensor(0.1166))
# ('т', tensor(0.1536))
# ('о', tensor(0.0919))
# ('н', tensor(0.0484))
# ('\n', tensor(0.0380))
# абстракционизм
# ('б', tensor(0.1092))
# ('с', tensor(0.0695))
# ('т', tensor(0.1589))
# ('р', tensor(0.1800))
# ('а', tensor(0.2656))
# ('к', tensor(0.0465))
# ('ц', tensor(0.0041))
# ('и', tensor(0.5383))
# ('о', tensor(0.0159))
# ('н', tensor(0.0485))
# ('и', tensor(0.0726))
# ('з', tensor(0.0120))
# ('м', tensor(0.0096))
# ('\n', tensor(0.0301))
# покрутить
# ('о', tensor(0.2441))
# ('к', tensor(0.0274))
# ('р', tensor(0.0666))
# ('у', tensor(0.1021))
# ('т', tensor(0.1862))
# ('и', tensor(0.1242))
# ('т', tensor(0.3478))
# ('ь', tensor(0.8750))
# ('\n', tensor(0.8211))
# ёмкий
# ('м', tensor(0.0619))
# ('к', tensor(0.1038))
# ('и', tensor(0.1884))
# ('й', tensor(0.2772))
# ('\n', tensor(0.7347))
# закрыться
# ('а', tensor(0.2866))
# ('к', tensor(0.0296))
# ('р', tensor(0.0963))
# ('ы', tensor(0.0797))
# ('т', tensor(0.0718))
# ('ь', tensor(0.3638))
# ('с', tensor(0.1208))
# ('я', tensor(0.7726))
# ('\n', tensor(0.8742))
# ссылаться
# ('с', tensor(0.0235))
# ('ы', tensor(0.0021))
# ('л', tensor(0.0549))
# ('а', tensor(0.2691))
# ('т', tensor(0.4223))
# ('ь', tensor(0.5343))
# ('с', tensor(0.2207))
# ('я', tensor(0.8228))
# ('\n', tensor(0.8872))
# ассигнование
# ('с', tensor(0.0762))
# ('с', tensor(0.0386))
# ('и', tensor(0.0769))
# ('г', tensor(0.0189))
# ('н', tensor(0.0252))
# ('о', tensor(0.1128))
# ('в', tensor(0.1239))
# ('а', tensor(0.2524))
# ('н', tensor(0.1167))
# ('и', tensor(0.1844))
# ('е', tensor(0.0567))
# ('\n', tensor(0.5427))
# собеседница
# ('о', tensor(0.1273))
# ('б', tensor(0.0870))
# ('е', tensor(0.1137))
# ('с', tensor(0.0796))
# ('е', tensor(0.0124))
# ('д', tensor(0.0304))
# ('н', tensor(0.0871))
# ('и', tensor(0.1831))
# ('ц', tensor(0.0215))
# ('а', tensor(0.1602))
# ('\n', tensor(0.6230))
# лихорадить
# ('и', tensor(0.0600))
# ('х', tensor(0.0078))
# ('о', tensor(0.1407))
# ('р', tensor(0.1398))
# ('а', tensor(0.2991))
# ('д', tensor(0.0348))
# ('и', tensor(0.1954))
# ('т', tensor(0.2530))
# ('ь', tensor(0.7598))
# ('\n', tensor(0.8248))
# афганка
# ('ф', tensor(0.0128))
# ('г', tensor(0.0290))
# ('а', tensor(0.1067))
# ('н', tensor(0.1058))
# ('к', tensor(0.0206))
# ('а', tensor(0.3916))
# ('\n', tensor(0.7063))
# обездолить
# ('б', tensor(0.1613))
# ('е', tensor(0.1127))
# ('з', tensor(0.0340))
# ('д', tensor(0.0784))
# ('о', tensor(0.2445))
# ('л', tensor(0.0688))
# ('и', tensor(0.1614))
# ('т', tensor(0.3842))
# ('ь', tensor(0.7092))
# ('\n', tensor(0.7264))
# стоячий
# ('т', tensor(0.1537))
# ('о', tensor(0.1433))
# ('я', tensor(0.0026))
# ('ч', tensor(0.0222))
# ('и', tensor(0.1503))
# ('й', tensor(0.0426))
# ('\n', tensor(0.9295))
# финн
# ('и', tensor(0.0465))
# ('н', tensor(0.0670))
# ('н', tensor(0.0863))
# ('\n', tensor(0.0010))
# союзница
# ('о', tensor(0.1273))
# ('ю', tensor(0.0012))
# ('з', tensor(0.0246))
# ('н', tensor(0.0487))
# ('и', tensor(0.1878))
# ('ц', tensor(0.0245))
# ('а', tensor(0.2082))
# ('\n', tensor(0.4817))
# страховщик
# ('т', tensor(0.1537))
# ('р', tensor(0.2643))
# ('а', tensor(0.1846))
# ('х', tensor(0.0232))
# ('о', tensor(0.0767))
# ('в', tensor(0.2243))
# ('щ', tensor(0.0022))
# ('и', tensor(0.4776))
# ('к', tensor(0.0268))
# ('\n', tensor(0.4587))
# мизансцена
# ('и', tensor(0.0986))
# ('з', tensor(0.0686))
# ('а', tensor(0.1513))
# ('н', tensor(0.0915))
# ('с', tensor(0.0383))
# ('ц', tensor(0.0040))
# ('е', tensor(0.0609))
# ('н', tensor(0.0907))
# ('а', tensor(0.0711))
# ('\n', tensor(0.1859))
# клиентский
# ('л', tensor(0.0320))
# ('и', tensor(0.2117))
# ('е', tensor(0.0167))
# ('н', tensor(0.2485))
# ('т', tensor(0.1338))
# ('с', tensor(0.0029))
# ('к', tensor(0.2155))
# ('и', tensor(0.3831))
# ('й', tensor(0.7497))
# ('\n', tensor(0.9382))
# конкуренция
# ('о', tensor(0.1939))
# ('н', tensor(0.0346))
# ('к', tensor(0.0289))
# ('у', tensor(0.0705))
# ('р', tensor(0.0860))
# ('е', tensor(0.0736))
# ('н', tensor(0.1833))
# ('ц', tensor(0.0054))
# ('и', tensor(0.3613))
# ('я', tensor(0.1747))
# ('\n', tensor(0.7717))
# антиген
# ('н', tensor(0.0729))
# ('т', tensor(0.0486))
# ('и', tensor(0.0611))
# ('г', tensor(0.0114))
# ('е', tensor(0.1673))
# ('н', tensor(0.1767))
# ('\n', tensor(0.0557))
# подарок
# ('о', tensor(0.2441))
# ('д', tensor(0.1116))
# ('а', tensor(0.0841))
# ('р', tensor(0.0829))
# ('о', tensor(0.1131))
# ('к', tensor(0.0363))
# ('\n', tensor(0.1645))
# общеобразовательный
# ('б', tensor(0.1613))
# ('щ', tensor(0.0058))
# ('е', tensor(0.2475))
# ('о', tensor(0.0104))
# ('б', tensor(0.0980))
# ('р', tensor(0.0207))
# ('а', tensor(0.4014))
# ('з', tensor(0.0302))
# ('о', tensor(0.0355))
# ('в', tensor(0.2593))
# ('а', tensor(0.3505))
# ('т', tensor(0.5160))
# ('е', tensor(0.0140))
# ('л', tensor(0.1505))
# ('ь', tensor(0.7556))
# ('н', tensor(0.3555))
# ('ы', tensor(0.7606))
# ('й', tensor(0.9288))
# ('\n', tensor(0.9795))
# военно-политический
# ('о', tensor(0.1924))
# ('е', tensor(0.0223))
# ('н', tensor(0.1789))
# ('н', tensor(0.1486))
# ('о', tensor(0.0788))
# ('-', tensor(0.0048))
# ('п', tensor(0.0015))
# ('о', tensor(0.2079))
# ('л', tensor(0.0660))
# ('и', tensor(0.1270))
# ('т', tensor(0.3261))
# ('и', tensor(0.0388))
# ('ч', tensor(0.0344))
# ('е', tensor(0.1216))
# ('с', tensor(0.3017))
# ('к', tensor(0.5200))
# ('и', tensor(0.3886))
# ('й', tensor(0.8312))
# ('\n', tensor(0.9424))
# вдавливаться
# ('д', tensor(0.0007))
# ('а', tensor(0.0628))
# ('в', tensor(0.0518))
# ('л', tensor(0.0384))
# ('и', tensor(0.1884))
# ('в', tensor(0.1203))
# ('а', tensor(0.2975))
# ('т', tensor(0.6023))
# ('ь', tensor(0.9317))
# ('с', tensor(0.1613))
# ('я', tensor(0.8572))
# ('\n', tensor(0.9072))
# хмыкать
# ('м', tensor(0.0044))
# ('ы', tensor(0.0287))
# ('к', tensor(0.0322))
# ('а', tensor(0.1828))
# ('т', tensor(0.1885))
# ('ь', tensor(0.6710))
# ('\n', tensor(0.7814))
# абсент
# ('б', tensor(0.1092))
# ('с', tensor(0.0695))
# ('е', tensor(0.0790))
# ('н', tensor(0.1387))
# ('т', tensor(0.1094))
# ('\n', tensor(0.0083))
# импликация
# ('м', tensor(0.0411))
# ('п', tensor(0.0231))
# ('л', tensor(0.0192))
# ('и', tensor(0.2348))
# ('к', tensor(0.0701))
# ('а', tensor(0.2393))
# ('ц', tensor(0.0059))
# ('и', tensor(0.3666))
# ('я', tensor(0.1873))
# ('\n', tensor(0.8245))
# рушение
# ('у', tensor(0.0563))
# ('ш', tensor(0.0449))
# ('е', tensor(0.0937))
# ('н', tensor(0.0870))
# ('и', tensor(0.1061))
# ('е', tensor(0.0501))
# ('\n', tensor(0.3870))
# репей
# ('е', tensor(0.1883))
# ('п', tensor(0.0506))
# ('е', tensor(0.1271))
# ('й', tensor(0.0025))
# ('\n', tensor(0.4050))
# горбатый
# ('о', tensor(0.2068))
# ('р', tensor(0.1543))
# ('б', tensor(0.0196))
# ('а', tensor(0.1372))
# ('т', tensor(0.1830))
# ('ы', tensor(0.0104))
# ('й', tensor(0.2425))
# ('\n', tensor(0.9681))
# биографический
# ('и', tensor(0.0785))
# ('о', tensor(0.0139))
# ('г', tensor(0.0619))
# ('р', tensor(0.1213))
# ('а', tensor(0.3336))
# ('ф', tensor(0.0094))
# ('и', tensor(0.0732))
# ('ч', tensor(0.0512))
# ('е', tensor(0.1375))
# ('с', tensor(0.2126))
# ('к', tensor(0.4277))
# ('и', tensor(0.4156))
# ('й', tensor(0.8399))
# ('\n', tensor(0.9508))

# %% [markdown]
# По вероятностям видно, что модель хорошо угадывает окончания. (особенно последнюю букву й у длинных слов)
